# %% [markdown]
# #Lyrics Extraction
# This notebook continues the processing pipeline. It applies offline scraping on each available lyric page from [Lyrics-Raw-Harvesting Notebook](Lyrics-Raw-Harvesting.ipynb). It builds a cache (i.e. persistence) of extracted song lyrics in order to pick up on processing as needed without duplicating the need to re-process valid results.
# * [lw-extracted-lyrics](../../data/harvested/lw-extracted-lyrics) is the directory for extracted song lyrics
# * [lw-extracted-lyrics-error](../../data/harvested/lw-extracted-lyrics-error) is the directory for lyrics unable to be processed, requiring some sort of manual intervention. After being corrected, additional processing units should remain unaware of manual intervention.
#
# Lyrics extraction is done in an offline manner. It works against all available raw songs from lyrics.wikia within [lw-raw-lyrics](../../data/harvested/lw-raw-lyrics).

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# %%
## MLJ: Additional Extras
from bs4 import BeautifulSoup
import io
import os
import requests
import time
import itertools
import json
import pickle

# %% [markdown]
# ##Load Lyrics Dataframe

# %%
# load the latest master lyricsdf
lyricsdf = pd.read_csv("../../data/conditioned/master-lyricsdf.csv")

# %%
lyricsdf.head()
# Out:
#    position  year                                         title.href                              title               artist                                             lyrics  decade song_key                                         lyrics_url                                    lyrics_abstract
# 0         1  1970  https://en.wikipedia.org/wiki/Bridge_over_Trou...         Bridge over Troubled Water  Simon and Garfunkel  When you're weary feeling small When tears are...    1970   1970-1  http://lyrics.wikia.com/Simon_And_Garfunkel:Br...  When you're weary\nFeeling small\nWhen tears a...
# 1         2  1970  https://en.wikipedia.org/wiki/(They_Long_to_Be...     (They Long to Be) Close to You       The Carpenters                                                  x    1970   1970-2  http://lyrics.wikia.com/Carpenters:%28They_Lon...  Why do birds suddenly appear\nEverytime you ar...
# 2         3  1970  https://en.wikipedia.org/wiki/American_Woman_(...                     American Woman        The Guess Who  American woman, stay away from me American wom...    1970   1970-3  http://lyrics.wikia.com/The_Guess_Who:American...  Mmm, da da da\nMmm, mmm, da da da\nMmm, mmm, d...
# 3         4  1970  https://en.wikipedia.org/wiki/Raindrops_Keep_F...  Raindrops Keep Fallin' on My Head          B.J. Thomas  Raindrops keep falling on my head Just like th...    1970   1970-4  http://lyrics.wikia.com/B.J._Thomas:Raindrops_...  Raindrops are falling on my head\nAnd just lik...
# 4         5  1970  https://en.wikipedia.org/wiki/War_(Edwin_Starr...                                War          Edwin Starr  War huh Yeah! Absolutely uh-huh, uh-huh huh Ye...    1970   1970-5            http://lyrics.wikia.com/Edwin_Starr:War  War, huh, yeah\nWhat is it good for?\nAbsolute...

# %% [markdown]
# ##Setup Directories and File Utility Methods

# %%
lw_success_dir = "../../data/harvested/lw-extracted-lyrics/"
lw_issues_dir = "../../data/harvested/lw-extracted-lyrics-error/"
lw_raw_dir = "../../data/harvested/lw-raw-lyrics/" #must look for raw here

# %%
# adapted from https://justgagan.wordpress.com/2010/09/22/python-create-path-or-directories-if-not-exist/
def assureDirExists(path):
    d = os.path.dirname(path)
    if not os.path.exists(d):
        os.makedirs(d)

# %%
# make sure the directories exist
assureDirExists(lw_success_dir)
assureDirExists(lw_issues_dir)
assureDirExists(lw_raw_dir)

# %%
# adapted from http://stackoverflow.com/questions/82831/check-whether-a-file-exists-using-python
def isNonZeroFile(fpath):  
    return True if os.path.isfile(fpath) and os.path.getsize(fpath) > 0 else False

# %%
# consolidated helper method for paths to be used in writing success and issues as needed.
# note *_hpath used here vs *_jpath in previous notebook.
def buildPathsDictFor(song_key):
    """
    return a dictionary of paths for the `song_key`
    """
    success_path = "{}{}.txt".format(lw_success_dir,song_key) #normal results    
    issues_path = "{}{}.txt".format(lw_issues_dir,song_key) #text with issue message
    raw_path = "{}{}.html".format(lw_raw_dir,song_key) #raw html from lyrics.wikia
    return {'song_key':song_key, 'success_path':success_path, 'issues_path':issues_path, 'raw_path':raw_path}

# %%
# consolidated helper method for result writes
def writeStrToFile(s, pathsd, pathsd_key):
    """
    write the given str to the given path.
    
     --- Input ---
    str: String to write
    pathsd: Dictionary holding paths
    pathsd_key: String key to use in pathsd when writing
    
    --- Return ---
    pathsd[pathsd_key]
    """
    path = pathsd[pathsd_key]
    
    with io.open(path,'w',encoding='utf-8') as text_file:
        if isinstance(s, str):
            text_file.write(unicode(s,encoding='utf-8'))
        elif isinstance(s, unicode):        
            text_file.write(s)
    
    return path

# %% [markdown]
# ##Common Utilities

# %%
# common cleaning for lyrics, good for both full and abstracts.
def normalizeLyrics(string):
    # catch weird trailing lines
    lyrics = string.replace("\n.","") 
        
    # catch double periods with spaces.
    lyrics = lyrics.replace(". . ",". ").replace("?. ","? ").replace("!. ","! ").replace(",. ",", ")
        
    # catch double spaces and hanging periods
    lyrics = lyrics.replace("  "," ").replace(" .",".")
    
    # convert newline to '. ' 
    lyrics = lyrics.replace("\n",". ")
    
    # catch ellipses and double periods and strip
    lyrics = lyrics.replace("...",".").replace("..",".").strip() 
    
    return lyrics

# %% [markdown]
# ##Grab or Identify Cached Song Lyrics

# %%
# get lyrics within bs4.element.Tag lyricbox into the right output
from bs4 import Comment

def cleanLyrics(lyricbox, debug=False):
    """
    clean lyrics starting from the beautiful soup initial results at bs4.element.Tag lyricbox
    """
    lyrics = None
    try:
        # kill all script and style elements in lyricsbox as well as the meta paragraph
        # from http://stackoverflow.com/questions/5598524/can-i-remove-script-tags-with-beautifulsoup
        for script in lyricbox(["script", "style"]):
            script.extract()    # rip it out
        
        # kill all comments
        # from http://stackoverflow.com/questions/23299557/beautifulsoup-4-remove-comment-tag-and-its-content
        for child in lyricbox:
            if isinstance(child,Comment):
                child.extract()
        
        llist = lyricbox.contents # use this versus getText() to keep breaks
        if debug:  
            print "len contents --> ", len(llist)
            print "contents -->\n", llist
        
        # replace '<br/>' with '.'
        lyrics = "".join([x if isinstance(x,unicode) else ". " for x in llist])
        
        lyrics = normalizeLyrics(lyrics) # common cleaning
        
        # catch missing final punctuation
        if not lyrics.endswith("."):
            lyrics = lyrics + "."
        
    except Exception as e:
        print e
        lyrics = None
    
    if debug:
        print"---START ::: CLEAN LYRICS ---"
        print lyrics
        print"---END ::: CLEAN LYRICS ---"
    
    return lyrics

# %%
def cachedLyricsOrExtract(pathsd, force=False, debug=False):
    """
    Leverage cache where possible; helpful for reprocessing. This will use
    `song_key` to lookup available results within data/harvested/lw-extracted-lyrics.
    
    Successful results are within data/harvested/lw-extracted-lyrics/<song_key>.txt
    Unsuccessful result are within data/harvested/lw-extracted-lyrics-error/<song_key>.txt
    
     --- Input ---    
    pathsd: Dictionary provided with paths to use as well as `song_key`
    force: optional Boolean to indicate full processing, ignoring cache, default = False
    debug: optional Boolean to indicate more verbose output
    
    --- Return ---
    tuple of the following:
    t[0] String path to processing results, 
    t[1] Boolean indicating True for success, False for issue
    t[2] Boolean indicating True for cache results, else False
    """  
    
    song_key = pathsd['song_key']
    
    #if not force and is in the cache (i.e. already persisted) just return it
    if not force and isNonZeroFile(pathsd['success_path']):
        print "... using song lyric in cache for ", song_key
        return pathsd['success_path'], True, True #success_path, success, cache
    elif not isNonZeroFile(pathsd['raw_path']):
        if debug:
            print "... no raw song lyric in cache to extract for ", song_key
        return pathsd['issues_path'], False, False #issues_path, not success, not cache
    
    # have an extracted lyric at the raw path, attempt processing.
    try:
        
        print "... attempting to extract song_key: ", song_key
        
        # Read text from raw 
        with io.open(pathsd['raw_path'], "r", encoding='utf-8') as text_file:
            text = text_file.read()
        
        # attempt to parse with BeautifulSoup
        soup = BeautifulSoup(text, "html.parser")        
        
        lyricbox = soup.find("div", attrs={"class": "lyricbox"}) #get first
        
        # punt off to cleaner
        lyrics = cleanLyrics(lyricbox, debug)  
              
        if lyrics:                    
            return writeStrToFile(lyrics, pathsd, 'success_path'), True, False #success_path, success, not cache
        
        # essentially, else 
        msg = "Not able to process lyrics for song_key: `{}`".format(song_key)
        return writeStrToFile(msg, pathsd, 'issues_path'), False, False #issues_path, not success, not cache
    
    except Exception as e:
        msg = "exception processing lyrics for song_key: `{}`, {}".format(song_key,e)
        print msg
        return writeStrToFile(msg, pathsd, 'issues_path'), False, False #issues_path, not success, not cache

# %%
# main entry-point for extracted lyric processing
def extractAvailableRawSongLyrics(df, force=False, debug=False):
    """
    Attempt to extract raw lyrics downloaded from lyrics.wikia, skipping successfully persisted previous results.
    Each song_key result is individually persisted to file for repeat / additive processing pipeline.
    
     --- Input ---
    df: Dataframe from which to build and cache results   
    force: optional Boolean to indicate full processing, ignoring cache, default = False
    debug: optional Boolean to indicate more verbose output
    
    --- Return ---
    tuple of the following:
    t[0] dictionary of new processing by song_key with path to results,
    t[1] dictionary of existing / cached processing by song_key with path to results,
    t[2] dictionary of issues by song_key with path to results 
    """   
    cache_refs = {}
    new_refs = {}
    issues = {}    
    
    for r in df.iterrows():
        song_key = r[1].song_key
        
        pathsd = buildPathsDictFor(song_key)
            
        # let this call handle download or skip based on cache 
        # the following returns tuple with the following:
        # t[0] String path to processing results, 
        # t[1] Boolean indicating True if success or False if issue
        # t[2] Boolean indicating 'True' if results from cache
        t = cachedLyricsOrExtract(pathsd,force=force,debug=debug)
            
        # cached results (ignored)
        if t[2] and t[1]:
            cache_refs[song_key] = t[0]
        # new results    
        elif t[1]:
            new_refs[song_key] = t[0]
        # issues    
        else:    
            issues[song_key] = t[0]
        
    return new_refs, cache_refs, issues

# %% [markdown]
# ###Quick Test to Verify Handling a Single Key

# %%
# quick test
ttuple = extractAvailableRawSongLyrics(lyricsdf[lyricsdf.song_key == "2001-96"], debug=True, force=True)   
print
print "how many new lyrics were downloaded? ", len(ttuple[0])
print "how many results were in the cache? ", len(ttuple[1])
print "how many issues were encountered? ", len(ttuple[2])

print ttuple[0]
# Out:
# ... attempting to extract song_key:  2001-96
# len contents -->  110
# contents -->
# [u'He spends his nights in California', <br/>, u'Watching the stars on the big screen', <br/>, u'And then he lies awake and he wonders', <br/>, u'"Why can\'t that be me?"', <br/>, <br/>, u"'Cause in his life he's filled with all these good intentions", <br/>, u"He's left a lot of things he'd rather not mention right now", <br/>, u'Just before he says goodnight', <br/>, u'He looks up with a little smile at me and he says', <br/>, <br/>, u'If I could be like that', <br/>, u'I would give anything', <br/>, u'Just to live one day', <br/>, u'In those shoes', <br/>, u'If I could be like that, what would I do?', <br/>, u'What would I do? Yeah', <br/>, <br/>, u'Now in dreams we run', <br/>, <br/>, u'She spends her days up in the north park', <br/>, u'Watching the people as they pass', <br/>, u'And all she wants is just a little piece of this dream', <br/>, u'Is that too much to ask?', <br/>, u'With a safe home, and a warm bed, on a quiet little street', <br/>, u'All she wants is just that something to hold on to', <br/>, u"That's all she needs, yeah", <br/>, <br/>, u'If I could be like that ', <br/>, u'I would give anything', <br/>, u'Just to live one day', <br/>, u'In those shoes', <br/>, u'If I could be like that, what would I do?', <br/>, u'What would I do? Yeah', <br/>, <br/>, u"I'm falling into this, in dreams we run away", <br/>, <br/>, u'If I could be like that ', <br/>, u'I would give anything', <br/>, u'Just to live one day', <br/>, u'In those shoes', <br/>, u'If I could be like that, what would I do?', <br/>, u'What would I do?', <br/>, <br/>, u'If I could be like that ', <br/>, u'I would give anything', <br/>, u'Just to live one day', <br/>, u'In those shoes', <br/>, u'If I could be like that, what would I do?', <br/>, u'What would I do?', <br/>, <br/>, u'If I could be like that ', <br/>, u'I would give anything', <br/>, u'Just to live one day', <br/>, u'In those shoes', <br/>, u'If I could be like that, what would I do?', <br/>, u'Lord what would I do?', <br/>, <br/>, u'Falling in', <br/>, u'I feel I am falling in to this again\n', u'\n', <div class="lyricsbreak"></div>, u'\n']
# ---START ::: CLEAN LYRICS ---
# He spends his nights in California. Watching the stars on the big screen. And then he lies awake and he wonders. "Why can't that be me?". 'Cause in his life he's filled with all these good intentions. He's left a lot of things he'd rather not mention right now. Just before he says goodnight. He looks up with a little smile at me and he says. If I could be like that. I would give anything. Just to live one day. In those shoes. If I could be like that, what would I do? What would I do? Yeah. Now in dreams we run. She spends her days up in the north park. Watching the people as they pass. And all she wants is just a little piece of this dream. Is that too much to ask? With a safe home, and a warm bed, on a quiet little street. All she wants is just that something to hold on to. That's all she needs, yeah. If I could be like that. I would give anything. Just to live one day. In those shoes. If I could be like that, what would I do? What would I do? Yeah. I'm falling into this, in dreams we run away. If I could be like that. I would give anything. Just to live one day. In those shoes. If I could be like that, what would I do? What would I do? If I could be like that. I would give anything. Just to live one day. In those shoes. If I could be like that, what would I do? What would I do? If I could be like that. I would give anything. Just to live one day. In those shoes. If I could be like that, what would I do? Lord what would I do? Falling in. I feel I am falling in to this again.
# ---END ::: CLEAN LYRICS ---
#
# how many new lyrics were downloaded?  1
# how many results were in the cache?  0
# how many issues were encountered?  0
# {'2001-96': '../../data/harvested/lw-extracted-lyrics/2001-96.txt'}

# %% [markdown]
# ##Process the 1970s
# Validate process prior to committing to all decades

# %%
print "execution start --> {}".format(time.strftime('%a, %d %b %Y %H:%M:%S', time.localtime()))
# Out:
# execution start --> Mon, 23 Nov 2015 17:04:42

# %%
# %%time
# process 70s
new_refs70, cache_refs70, issues70 = extractAvailableRawSongLyrics(lyricsdf[lyricsdf.decade == 1970])
# Out:
# ... attempting to extract song_key:  1970-1
# ... attempting to extract song_key:  1970-2
# ... attempting to extract song_key:  1970-3
# ... attempting to extract song_key:  1970-4
# ... attempting to extract song_key:  1970-5
# ... attempting to extract song_key:  1970-6
# ... attempting to extract song_key:  1970-7
# ... attempting to extract song_key:  1970-8
# ... attempting to extract song_key:  1970-9
# ... attempting to extract song_key:  1970-10
# ... attempting to extract song_key:  1970-11
# ... attempting to extract song_key:  1970-12
# ... attempting to extract song_key:  1970-13
# ... attempting to extract song_key:  1970-14
# ... attempting to extract song_key:  1970-15
# ... attempting to extract song_key:  1970-16
# ... attempting to extract song_key:  1970-17
# ... attempting to extract song_key:  1970-18
# ... attempting to extract song_key:  1970-19
# ... attempting to extract song_key:  1970-20
# ... attempting to extract song_key:  1970-21
# ... attempting to extract song_key:  1970-22
# ... attempting to extract song_key:  1970-23
# ... attempting to extract song_key:  1970-24
# ... attempting to extract song_key:  1970-25
# ... attempting to extract song_key:  1970-26
# ... attempting to extract song_key:  1970-27
# ... attempting to extract song_key:  1970-28
# ... attempting to extract song_key:  1970-30
# ... attempting to extract song_key:  1970-31
# ... attempting to extract song_key:  1970-32
# ... attempting to extract song_key:  1970-33
# ... attempting to extract song_key:  1970-34
# ... attempting to extract song_key:  1970-35
# ... attempting to extract song_key:  1970-36
# ... attempting to extract song_key:  1970-37
# ... attempting to extract song_key:  1970-38
# ... attempting to extract song_key:  1970-39
# ... attempting to extract song_key:  1970-40
# ... attempting to extract song_key:  1970-41
# ... attempting to extract song_key:  1970-42
# ... attempting to extract song_key:  1970-43
# ... attempting to extract song_key:  1970-44
# ... attempting to extract song_key:  1970-45
# ... attempting to extract song_key:  1970-46
# ... attempting to extract song_key:  1970-47
# ... attempting to extract song_key:  1970-48
# ... attempting to extract song_key:  1970-49
# ... attempting to extract song_key:  1970-51
# ... attempting to extract song_key:  1970-52
# ... attempting to extract song_key:  1970-53
# ... attempting to extract song_key:  1970-54
# ... attempting to extract song_key:  1970-55
# ... attempting to extract song_key:  1970-56
# ... attempting to extract song_key:  1970-58
# ... attempting to extract song_key:  1970-59
# ... attempting to extract song_key:  1970-61
# ... attempting to extract song_key:  1970-62
# ... attempting to extract song_key:  1970-63
# ... attempting to extract song_key:  1970-64
# ... attempting to extract song_key:  1970-65
# ... attempting to extract song_key:  1970-66
# ... attempting to extract song_key:  1970-67
# ... attempting to extract song_key:  1970-68
# ... attempting to extract song_key:  1970-69
# ... attempting to extract song_key:  1970-70
# ... attempting to extract song_key:  1970-71
# ... attempting to extract song_key:  1970-72
# ... attempting to extract song_key:  1970-73
# ... attempting to extract song_key:  1970-74
# ... attempting to extract song_key:  1970-75
# ... attempting to extract song_key:  1970-76
# ... attempting to extract song_key:  1970-77
# ... attempting to extract song_key:  1970-78
# ... attempting to extract song_key:  1970-79
# ... attempting to extract song_key:  1970-80
# ... attempting to extract song_key:  1970-81
# ... attempting to extract song_key:  1970-82
# ... attempting to extract song_key:  1970-83
# ... attempting to extract song_key:  1970-84
# ... attempting to extract song_key:  1970-85
# ... attempting to extract song_key:  1970-86
# ... attempting to extract song_key:  1970-87
# ... attempting to extract song_key:  1970-88
# ... attempting to extract song_key:  1970-89
# ... attempting to extract song_key:  1970-90
# ... attempting to extract song_key:  1970-91
# ... attempting to extract song_key:  1970-92
# ... attempting to extract song_key:  1970-93
# ... attempting to extract song_key:  1970-94
# ... attempting to extract song_key:  1970-95
# ... attempting to extract song_key:  1970-96
# 'NoneType' object is not callable
# ... attempting to extract song_key:  1970-97
# ... attempting to extract song_key:  1970-98
# ... attempting to extract song_key:  1970-99
# ... attempting to extract song_key:  1970-100
# ... attempting to extract song_key:  1971-1
# ... attempting to extract song_key:  1971-2
# ... attempting to extract song_key:  1971-3
# ... attempting to extract song_key:  1971-4
# ... attempting to extract song_key:  1971-5
# ... attempting to extract song_key:  1971-6
# ... attempting to extract song_key:  1971-7
# ... attempting to extract song_key:  1971-8
# ... attempting to extract song_key:  1971-9
# ... attempting to extract song_key:  1971-10
# ... attempting to extract song_key:  1971-11
# ... attempting to extract song_key:  1971-12
# ... attempting to extract song_key:  1971-13
# ... attempting to extract song_key:  1971-14
# ... attempting to extract song_key:  1971-15
# ... attempting to extract song_key:  1971-16
# ... attempting to extract song_key:  1971-17
# ... attempting to extract song_key:  1971-18
# ... attempting to extract song_key:  1971-19
# ... attempting to extract song_key:  1971-20
# ... attempting to extract song_key:  1971-21
# ... attempting to extract song_key:  1971-23
# ... attempting to extract song_key:  1971-24
# ... attempting to extract song_key:  1971-25
# ... attempting to extract song_key:  1971-26
# ... attempting to extract song_key:  1971-28
# ... attempting to extract song_key:  1971-29
# ... attempting to extract song_key:  1971-30
# ... attempting to extract song_key:  1971-31
# ... attempting to extract song_key:  1971-32
# ... attempting to extract song_key:  1971-33
# ... attempting to extract song_key:  1971-34
# 'NoneType' object is not callable
# ... attempting to extract song_key:  1971-35
# ... attempting to extract song_key:  1971-36
# ... attempting to extract song_key:  1971-37
# ... attempting to extract song_key:  1971-38
# ... attempting to extract song_key:  1971-39
# ... attempting to extract song_key:  1971-40
# ... attempting to extract song_key:  1971-41
# ... attempting to extract song_key:  1971-42
# ... attempting to extract song_key:  1971-43
# ... attempting to extract song_key:  1971-44
# ... attempting to extract song_key:  1971-46
# ... attempting to extract song_key:  1971-47
# ... attempting to extract song_key:  1971-48
# ... attempting to extract song_key:  1971-49
# ... attempting to extract song_key:  1971-50
# ... attempting to extract song_key:  1971-51
# ... attempting to extract song_key:  1971-53
# ... attempting to extract song_key:  1971-54
# ... attempting to extract song_key:  1971-55
# ... attempting to extract song_key:  1971-56
# ... attempting to extract song_key:  1971-57
# ... attempting to extract song_key:  1971-58
# ... attempting to extract song_key:  1971-59
# ... attempting to extract song_key:  1971-60
# ... attempting to extract song_key:  1971-61
# ... attempting to extract song_key:  1971-62
# ... attempting to extract song_key:  1971-63
# ... attempting to extract song_key:  1971-64
# ... attempting to extract song_key:  1971-65
# ... attempting to extract song_key:  1971-66
# ... attempting to extract song_key:  1971-68
# ... attempting to extract song_key:  1971-69
# ... attempting to extract song_key:  1971-72
# 'NoneType' object is not callable
# ... attempting to extract song_key:  1971-73
# ... attempting to extract song_key:  1971-74
# ... attempting to extract song_key:  1971-75
# ... attempting to extract song_key:  1971-76
# ... attempting to extract song_key:  1971-77
# ... attempting to extract song_key:  1971-78
# 'NoneType' object is not callable
# ... attempting to extract song_key:  1971-79
# ... attempting to extract song_key:  1971-80
# ... attempting to extract song_key:  1971-81
# ... attempting to extract song_key:  1971-82
# ... attempting to extract song_key:  1971-83
# ... attempting to extract song_key:  1971-84
# ... attempting to extract song_key:  1971-85
# ... attempting to extract song_key:  1971-86
# ... attempting to extract song_key:  1971-87
# ... attempting to extract song_key:  1971-88
# ... attempting to extract song_key:  1971-89
# ... attempting to extract song_key:  1971-90
# ... attempting to extract song_key:  1971-91
# ... attempting to extract song_key:  1971-93
# ... attempting to extract song_key:  1971-94
# ... attempting to extract song_key:  1971-95
# ... attempting to extract song_key:  1971-96
# ... attempting to extract song_key:  1971-98
# ... attempting to extract song_key:  1971-99
# ... attempting to extract song_key:  1972-1
# ... attempting to extract song_key:  1972-2
# ... attempting to extract song_key:  1972-3
# ... attempting to extract song_key:  1972-4
# ... attempting to extract song_key:  1972-5
# ... attempting to extract song_key:  1972-6
# ... attempting to extract song_key:  1972-7
# ... attempting to extract song_key:  1972-8
# 'NoneType' object is not callable
# ... attempting to extract song_key:  1972-9
# ... attempting to extract song_key:  1972-10
# ... attempting to extract song_key:  1972-11
# ... attempting to extract song_key:  1972-12
# ... attempting to extract song_key:  1972-13
# ... attempting to extract song_key:  1972-14
# ... attempting to extract song_key:  1972-15
# ... attempting to extract song_key:  1972-16
# ... attempting to extract song_key:  1972-17
# ... attempting to extract song_key:  1972-18
# ... attempting to extract song_key:  1972-19
# ... attempting to extract song_key:  1972-20
# ... attempting to extract song_key:  1972-21
# ... attempting to extract song_key:  1972-22
# ... attempting to extract song_key:  1972-23
# ... attempting to extract song_key:  1972-24
# ... attempting to extract song_key:  1972-26
# ... attempting to extract song_key:  1972-27
# ... attempting to extract song_key:  1972-28
# ... attempting to extract song_key:  1972-29
# ... attempting to extract song_key:  1972-30
# ... attempting to extract song_key:  1972-31
# ... attempting to extract song_key:  1972-32
# ... attempting to extract song_key:  1972-33
# ... attempting to extract song_key:  1972-34
# ... attempting to extract song_key:  1972-35
# ... attempting to extract song_key:  1972-36
# ... attempting to extract song_key:  1972-37
# ... attempting to extract song_key:  1972-38
# ... attempting to extract song_key:  1972-39
# ... attempting to extract song_key:  1972-40
# ... attempting to extract song_key:  1972-41
# ... attempting to extract song_key:  1972-42
# ... attempting to extract song_key:  1972-44
# ... attempting to extract song_key:  1972-45
# ... attempting to extract song_key:  1972-46
# ... attempting to extract song_key:  1972-47
# ... attempting to extract song_key:  1972-48
# ... attempting to extract song_key:  1972-49
# ... attempting to extract song_key:  1972-50
# ... attempting to extract song_key:  1972-51
# ... attempting to extract song_key:  1972-52
# ... attempting to extract song_key:  1972-53
# ... attempting to extract song_key:  1972-54
# ... attempting to extract song_key:  1972-56
# ... attempting to extract song_key:  1972-57
# ... attempting to extract song_key:  1972-58
# ... attempting to extract song_key:  1972-59
# ... attempting to extract song_key:  1972-60
# ... attempting to extract song_key:  1972-61
# ... attempting to extract song_key:  1972-62
# ... attempting to extract song_key:  1972-63
# ... attempting to extract song_key:  1972-64
# ... attempting to extract song_key:  1972-65
# ... attempting to extract song_key:  1972-66
# ... attempting to extract song_key:  1972-67
# ... attempting to extract song_key:  1972-68
# ... attempting to extract song_key:  1972-69
# ... attempting to extract song_key:  1972-70
# ... attempting to extract song_key:  1972-71
# ... attempting to extract song_key:  1972-72
# ... attempting to extract song_key:  1972-73
# ... attempting to extract song_key:  1972-74
# ... attempting to extract song_key:  1972-75
# ... attempting to extract song_key:  1972-76
# ... attempting to extract song_key:  1972-77
# ... attempting to extract song_key:  1972-78
# ... attempting to extract song_key:  1972-79
# ... attempting to extract song_key:  1972-80
# ... attempting to extract song_key:  1972-81
# ... attempting to extract song_key:  1972-82
# ... attempting to extract song_key:  1972-83
# ... attempting to extract song_key:  1972-84
# ... attempting to extract song_key:  1972-85
# ... attempting to extract song_key:  1972-86
# ... attempting to extract song_key:  1972-87
# ... attempting to extract song_key:  1972-88
# ... attempting to extract song_key:  1972-89
# ... attempting to extract song_key:  1972-90
# ... attempting to extract song_key:  1972-91
# ... attempting to extract song_key:  1972-92
# ... attempting to extract song_key:  1972-93
# ... attempting to extract song_key:  1972-94
# ... attempting to extract song_key:  1972-96
# ... attempting to extract song_key:  1972-97
# ... attempting to extract song_key:  1972-98
# ... attempting to extract song_key:  1972-99
# ... attempting to extract song_key:  1972-100
# ... attempting to extract song_key:  1973-1
# ... attempting to extract song_key:  1973-2
# ... attempting to extract song_key:  1973-3
# ... attempting to extract song_key:  1973-4
# ... attempting to extract song_key:  1973-6
# ... attempting to extract song_key:  1973-7
# ... attempting to extract song_key:  1973-8
# ... attempting to extract song_key:  1973-9
# ... attempting to extract song_key:  1973-10
# ... attempting to extract song_key:  1973-11
# ... attempting to extract song_key:  1973-12
# ... attempting to extract song_key:  1973-13
# ... attempting to extract song_key:  1973-14
# ... attempting to extract song_key:  1973-15
# ... attempting to extract song_key:  1973-16
# ... attempting to extract song_key:  1973-17
# ... attempting to extract song_key:  1973-18
# ... attempting to extract song_key:  1973-19
# ... attempting to extract song_key:  1973-20
# ... attempting to extract song_key:  1973-21
# ... attempting to extract song_key:  1973-22
# ... attempting to extract song_key:  1973-23
# ... attempting to extract song_key:  1973-24
# ... attempting to extract song_key:  1973-25
# ... attempting to extract song_key:  1973-26
# ... attempting to extract song_key:  1973-27
# ... attempting to extract song_key:  1973-28
# ... attempting to extract song_key:  1973-29
# ... attempting to extract song_key:  1973-30
# ... attempting to extract song_key:  1973-31
# ... attempting to extract song_key:  1973-32
# ... attempting to extract song_key:  1973-33
# ... attempting to extract song_key:  1973-34
# ... attempting to extract song_key:  1973-35
# ... attempting to extract song_key:  1973-36
# ... attempting to extract song_key:  1973-37
# ... attempting to extract song_key:  1973-38
# ... attempting to extract song_key:  1973-39
# ... attempting to extract song_key:  1973-40
# ... attempting to extract song_key:  1973-41
# ... attempting to extract song_key:  1973-42
# ... attempting to extract song_key:  1973-43
# ... attempting to extract song_key:  1973-44
# ... attempting to extract song_key:  1973-45
# ... attempting to extract song_key:  1973-46
# ... attempting to extract song_key:  1973-47
# ... attempting to extract song_key:  1973-48
# 'NoneType' object is not callable
# ... attempting to extract song_key:  1973-49
# ... attempting to extract song_key:  1973-50
# ... attempting to extract song_key:  1973-51
# ... attempting to extract song_key:  1973-52
# ... attempting to extract song_key:  1973-53
# ... attempting to extract song_key:  1973-54
# ... attempting to extract song_key:  1973-55
# ... attempting to extract song_key:  1973-57
# ... attempting to extract song_key:  1973-58
# ... attempting to extract song_key:  1973-59
# ... attempting to extract song_key:  1973-60
# ... attempting to extract song_key:  1973-62
# ... attempting to extract song_key:  1973-63
# ... attempting to extract song_key:  1973-64
# ... attempting to extract song_key:  1973-65
# ... attempting to extract song_key:  1973-66
# ... attempting to extract song_key:  1973-67
# ... attempting to extract song_key:  1973-68
# ... attempting to extract song_key:  1973-69
# ... attempting to extract song_key:  1973-70
# ... attempting to extract song_key:  1973-71
# ... attempting to extract song_key:  1973-72
# ... attempting to extract song_key:  1973-73
# ... attempting to extract song_key:  1973-74
# ... attempting to extract song_key:  1973-75
# ... attempting to extract song_key:  1973-76
# ... attempting to extract song_key:  1973-78
# ... attempting to extract song_key:  1973-79
# ... attempting to extract song_key:  1973-80
# ... attempting to extract song_key:  1973-81
# ... attempting to extract song_key:  1973-82
# ... attempting to extract song_key:  1973-83
# ... attempting to extract song_key:  1973-84
# ... attempting to extract song_key:  1973-85
# ... attempting to extract song_key:  1973-86
# ... attempting to extract song_key:  1973-87
# ... attempting to extract song_key:  1973-88
# ... attempting to extract song_key:  1973-89
# ... attempting to extract song_key:  1973-91
# ... attempting to extract song_key:  1973-92
# ... attempting to extract song_key:  1973-93
# ... attempting to extract song_key:  1973-94
# ... attempting to extract song_key:  1973-95
# ... attempting to extract song_key:  1973-96
# ... attempting to extract song_key:  1973-97
# ... attempting to extract song_key:  1973-98
# ... attempting to extract song_key:  1973-99
# ... attempting to extract song_key:  1973-100
# ... attempting to extract song_key:  1974-1
# ... attempting to extract song_key:  1974-2
# ... attempting to extract song_key:  1974-3
# ... attempting to extract song_key:  1974-4
# ... attempting to extract song_key:  1974-5
# ... attempting to extract song_key:  1974-6
# ... attempting to extract song_key:  1974-8
# ... attempting to extract song_key:  1974-9
# ... attempting to extract song_key:  1974-10
# ... attempting to extract song_key:  1974-11
# ... attempting to extract song_key:  1974-12
# ... attempting to extract song_key:  1974-13
# ... attempting to extract song_key:  1974-14
# ... attempting to extract song_key:  1974-15
# ... attempting to extract song_key:  1974-16
# ... attempting to extract song_key:  1974-17
# ... attempting to extract song_key:  1974-18
# ... attempting to extract song_key:  1974-19
# ... attempting to extract song_key:  1974-20
# ... attempting to extract song_key:  1974-21
# ... attempting to extract song_key:  1974-23
# ... attempting to extract song_key:  1974-24
# ... attempting to extract song_key:  1974-25
# ... attempting to extract song_key:  1974-26
# ... attempting to extract song_key:  1974-27
# ... attempting to extract song_key:  1974-28
# ... attempting to extract song_key:  1974-29
# ... attempting to extract song_key:  1974-30
# ... attempting to extract song_key:  1974-31
# ... attempting to extract song_key:  1974-32
# ... attempting to extract song_key:  1974-33
# ... attempting to extract song_key:  1974-34
# ... attempting to extract song_key:  1974-35
# ... attempting to extract song_key:  1974-36
# ... attempting to extract song_key:  1974-37
# ... attempting to extract song_key:  1974-38
# ... attempting to extract song_key:  1974-39
# ... attempting to extract song_key:  1974-40
# ... attempting to extract song_key:  1974-41
# ... attempting to extract song_key:  1974-42
# ... attempting to extract song_key:  1974-43
# ... attempting to extract song_key:  1974-44
# ... attempting to extract song_key:  1974-45
# ... attempting to extract song_key:  1974-46
# ... attempting to extract song_key:  1974-47
# ... attempting to extract song_key:  1974-48
# ... attempting to extract song_key:  1974-49
# ... attempting to extract song_key:  1974-50
# ... attempting to extract song_key:  1974-51
# ... attempting to extract song_key:  1974-52
# ... attempting to extract song_key:  1974-53
# ... attempting to extract song_key:  1974-54
# ... attempting to extract song_key:  1974-55
# ... attempting to extract song_key:  1974-56
# ... attempting to extract song_key:  1974-57
# ... attempting to extract song_key:  1974-58
# ... attempting to extract song_key:  1974-59
# ... attempting to extract song_key:  1974-60
# ... attempting to extract song_key:  1974-61
# ... attempting to extract song_key:  1974-62
# ... attempting to extract song_key:  1974-63
# ... attempting to extract song_key:  1974-64
# ... attempting to extract song_key:  1974-65
# ... attempting to extract song_key:  1974-66
# ... attempting to extract song_key:  1974-67
# ... attempting to extract song_key:  1974-68
# ... attempting to extract song_key:  1974-69
# ... attempting to extract song_key:  1974-70
# ... attempting to extract song_key:  1974-71
# ... attempting to extract song_key:  1974-72
# ... attempting to extract song_key:  1974-73
# ... attempting to extract song_key:  1974-74
# ... attempting to extract song_key:  1974-75
# ... attempting to extract song_key:  1974-76
# ... attempting to extract song_key:  1974-78
# ... attempting to extract song_key:  1974-79
# 'NoneType' object is not callable
# ... attempting to extract song_key:  1974-80
# ... attempting to extract song_key:  1974-82
# ... attempting to extract song_key:  1974-83
# ... attempting to extract song_key:  1974-84
# ... attempting to extract song_key:  1974-85
# ... attempting to extract song_key:  1974-86
# ... attempting to extract song_key:  1974-87
# ... attempting to extract song_key:  1974-88
# ... attempting to extract song_key:  1974-89
# ... attempting to extract song_key:  1974-90
# ... attempting to extract song_key:  1974-91
# ... attempting to extract song_key:  1974-93
# ... attempting to extract song_key:  1974-94
# ... attempting to extract song_key:  1974-95
# ... attempting to extract song_key:  1974-96
# ... attempting to extract song_key:  1974-97
# ... attempting to extract song_key:  1974-98
# ... attempting to extract song_key:  1974-100
# ... attempting to extract song_key:  1975-1
# ... attempting to extract song_key:  1975-2
# ... attempting to extract song_key:  1975-3
# ... attempting to extract song_key:  1975-4
# ... attempting to extract song_key:  1975-5
# ... attempting to extract song_key:  1975-6
# ... attempting to extract song_key:  1975-7
# ... attempting to extract song_key:  1975-8
# ... attempting to extract song_key:  1975-9
# ... attempting to extract song_key:  1975-10
# ... attempting to extract song_key:  1975-11
# ... attempting to extract song_key:  1975-12
# ... attempting to extract song_key:  1975-13
# ... attempting to extract song_key:  1975-14
# ... attempting to extract song_key:  1975-15
# ... attempting to extract song_key:  1975-16
# ... attempting to extract song_key:  1975-17
# ... attempting to extract song_key:  1975-18
# ... attempting to extract song_key:  1975-19
# ... attempting to extract song_key:  1975-20
# ... attempting to extract song_key:  1975-21
# ... attempting to extract song_key:  1975-22
# ... attempting to extract song_key:  1975-23
# ... attempting to extract song_key:  1975-24
# ... attempting to extract song_key:  1975-25
# ... attempting to extract song_key:  1975-26
# ... attempting to extract song_key:  1975-27
# ... attempting to extract song_key:  1975-28
# ... attempting to extract song_key:  1975-29
# ... attempting to extract song_key:  1975-30
# ... attempting to extract song_key:  1975-31
# ... attempting to extract song_key:  1975-32
# ... attempting to extract song_key:  1975-33
# ... attempting to extract song_key:  1975-34
# ... attempting to extract song_key:  1975-35
# ... attempting to extract song_key:  1975-36
# ... attempting to extract song_key:  1975-37
# ... attempting to extract song_key:  1975-38
# ... attempting to extract song_key:  1975-39
# ... attempting to extract song_key:  1975-40
# ... attempting to extract song_key:  1975-41
# ... attempting to extract song_key:  1975-42
# ... attempting to extract song_key:  1975-43
# ... attempting to extract song_key:  1975-44
# ... attempting to extract song_key:  1975-45
# ... attempting to extract song_key:  1975-46
# ... attempting to extract song_key:  1975-47
# ... attempting to extract song_key:  1975-48
# ... attempting to extract song_key:  1975-49
# ... attempting to extract song_key:  1975-50
# ... attempting to extract song_key:  1975-52
# ... attempting to extract song_key:  1975-53
# ... attempting to extract song_key:  1975-54
# ... attempting to extract song_key:  1975-55
# ... attempting to extract song_key:  1975-56
# ... attempting to extract song_key:  1975-57
# ... attempting to extract song_key:  1975-58
# ... attempting to extract song_key:  1975-59
# ... attempting to extract song_key:  1975-60
# ... attempting to extract song_key:  1975-61
# ... attempting to extract song_key:  1975-62
# ... attempting to extract song_key:  1975-63
# ... attempting to extract song_key:  1975-64
# ... attempting to extract song_key:  1975-65
# ... attempting to extract song_key:  1975-66
# 'NoneType' object is not callable
# ... attempting to extract song_key:  1975-67
# ... attempting to extract song_key:  1975-68
# ... attempting to extract song_key:  1975-69
# ... attempting to extract song_key:  1975-70
# ... attempting to extract song_key:  1975-71
# ... attempting to extract song_key:  1975-72
# ... attempting to extract song_key:  1975-74
# ... attempting to extract song_key:  1975-75
# ... attempting to extract song_key:  1975-76
# ... attempting to extract song_key:  1975-77
# ... attempting to extract song_key:  1975-78
# ... attempting to extract song_key:  1975-79
# ... attempting to extract song_key:  1975-80
# ... attempting to extract song_key:  1975-81
# ... attempting to extract song_key:  1975-82
# ... attempting to extract song_key:  1975-83
# ... attempting to extract song_key:  1975-84
# ... attempting to extract song_key:  1975-85
# ... attempting to extract song_key:  1975-86
# ... attempting to extract song_key:  1975-87
# ... attempting to extract song_key:  1975-89
# ... attempting to extract song_key:  1975-90
# ... attempting to extract song_key:  1975-91
# ... attempting to extract song_key:  1975-92
# ... attempting to extract song_key:  1975-93
# ... attempting to extract song_key:  1975-94
# ... attempting to extract song_key:  1975-95
# ... attempting to extract song_key:  1975-96
# ... attempting to extract song_key:  1975-97
# ... attempting to extract song_key:  1975-99
# ... attempting to extract song_key:  1976-1
# ... attempting to extract song_key:  1976-2
# ... attempting to extract song_key:  1976-3
# ... attempting to extract song_key:  1976-4
# ... attempting to extract song_key:  1976-5
# ... attempting to extract song_key:  1976-6
# ... attempting to extract song_key:  1976-7
# ... attempting to extract song_key:  1976-8
# ... attempting to extract song_key:  1976-9
# ... attempting to extract song_key:  1976-10
# ... attempting to extract song_key:  1976-11
# ... attempting to extract song_key:  1976-12
# ... attempting to extract song_key:  1976-13
# ... attempting to extract song_key:  1976-14
# ... attempting to extract song_key:  1976-15
# ... attempting to extract song_key:  1976-16
# ... attempting to extract song_key:  1976-17
# ... attempting to extract song_key:  1976-18
# ... attempting to extract song_key:  1976-19
# ... attempting to extract song_key:  1976-20
# ... attempting to extract song_key:  1976-21
# ... attempting to extract song_key:  1976-22
# ... attempting to extract song_key:  1976-23
# ... attempting to extract song_key:  1976-24
# ... attempting to extract song_key:  1976-25
# ... attempting to extract song_key:  1976-26
# ... attempting to extract song_key:  1976-27
# ... attempting to extract song_key:  1976-28
# ... attempting to extract song_key:  1976-29
# ... attempting to extract song_key:  1976-30
# ... attempting to extract song_key:  1976-31
# ... attempting to extract song_key:  1976-32
# ... attempting to extract song_key:  1976-33
# ... attempting to extract song_key:  1976-34
# ... attempting to extract song_key:  1976-35
# ... attempting to extract song_key:  1976-36
# ... attempting to extract song_key:  1976-37
# ... attempting to extract song_key:  1976-38
# ... attempting to extract song_key:  1976-39
# ... attempting to extract song_key:  1976-40
# ... attempting to extract song_key:  1976-41
# ... attempting to extract song_key:  1976-43
# ... attempting to extract song_key:  1976-44
# ... attempting to extract song_key:  1976-45
# ... attempting to extract song_key:  1976-46
# ... attempting to extract song_key:  1976-47
# ... attempting to extract song_key:  1976-48
# ... attempting to extract song_key:  1976-49
# ... attempting to extract song_key:  1976-50
# ... attempting to extract song_key:  1976-51
# ... attempting to extract song_key:  1976-52
# ... attempting to extract song_key:  1976-53
# ... attempting to extract song_key:  1976-54
# ... attempting to extract song_key:  1976-55
# ... attempting to extract song_key:  1976-56
# ... attempting to extract song_key:  1976-57
# 'NoneType' object is not callable
# ... attempting to extract song_key:  1976-58
# ... attempting to extract song_key:  1976-59
# ... attempting to extract song_key:  1976-60
# ... attempting to extract song_key:  1976-61
# ... attempting to extract song_key:  1976-62
# ... attempting to extract song_key:  1976-63
# ... attempting to extract song_key:  1976-64
# ... attempting to extract song_key:  1976-65
# ... attempting to extract song_key:  1976-66
# ... attempting to extract song_key:  1976-67
# ... attempting to extract song_key:  1976-69
# ... attempting to extract song_key:  1976-70
# ... attempting to extract song_key:  1976-71
# 'NoneType' object is not callable
# ... attempting to extract song_key:  1976-72
# ... attempting to extract song_key:  1976-73
# ... attempting to extract song_key:  1976-74
# ... attempting to extract song_key:  1976-75
# ... attempting to extract song_key:  1976-76
# ... attempting to extract song_key:  1976-77
# ... attempting to extract song_key:  1976-78
# ... attempting to extract song_key:  1976-79
# ... attempting to extract song_key:  1976-80
# ... attempting to extract song_key:  1976-81
# ... attempting to extract song_key:  1976-82
# ... attempting to extract song_key:  1976-83
# ... attempting to extract song_key:  1976-84
# ... attempting to extract song_key:  1976-85
# ... attempting to extract song_key:  1976-86
# 'NoneType' object is not callable
# ... attempting to extract song_key:  1976-87
# ... attempting to extract song_key:  1976-88
# ... attempting to extract song_key:  1976-89
# ... attempting to extract song_key:  1976-90
# ... attempting to extract song_key:  1976-91
# ... attempting to extract song_key:  1976-92
# ... attempting to extract song_key:  1976-93
# ... attempting to extract song_key:  1976-94
# ... attempting to extract song_key:  1976-95
# ... attempting to extract song_key:  1976-96
# ... attempting to extract song_key:  1976-97
# ... attempting to extract song_key:  1976-98
# ... attempting to extract song_key:  1976-99
# ... attempting to extract song_key:  1976-100
# ... attempting to extract song_key:  1977-1
# ... attempting to extract song_key:  1977-2
# ... attempting to extract song_key:  1977-3
# ... attempting to extract song_key:  1977-4
# ... attempting to extract song_key:  1977-5
# ... attempting to extract song_key:  1977-6
# ... attempting to extract song_key:  1977-7
# ... attempting to extract song_key:  1977-8
# ... attempting to extract song_key:  1977-9
# ... attempting to extract song_key:  1977-10
# ... attempting to extract song_key:  1977-11
# ... attempting to extract song_key:  1977-12
# ... attempting to extract song_key:  1977-13
# ... attempting to extract song_key:  1977-14
# ... attempting to extract song_key:  1977-15
# ... attempting to extract song_key:  1977-16
# ... attempting to extract song_key:  1977-17
# ... attempting to extract song_key:  1977-18
# ... attempting to extract song_key:  1977-19
# ... attempting to extract song_key:  1977-20
# ... attempting to extract song_key:  1977-21
# ... attempting to extract song_key:  1977-22
# ... attempting to extract song_key:  1977-23
# ... attempting to extract song_key:  1977-24
# ... attempting to extract song_key:  1977-25
# ... attempting to extract song_key:  1977-26
# ... attempting to extract song_key:  1977-27
# ... attempting to extract song_key:  1977-28
# ... attempting to extract song_key:  1977-29
# ... attempting to extract song_key:  1977-30
# ... attempting to extract song_key:  1977-31
# ... attempting to extract song_key:  1977-32
# ... attempting to extract song_key:  1977-33
# ... attempting to extract song_key:  1977-34
# ... attempting to extract song_key:  1977-35
# ... attempting to extract song_key:  1977-36
# ... attempting to extract song_key:  1977-37
# ... attempting to extract song_key:  1977-38
# ... attempting to extract song_key:  1977-39
# ... attempting to extract song_key:  1977-40
# ... attempting to extract song_key:  1977-41
# ... attempting to extract song_key:  1977-42
# ... attempting to extract song_key:  1977-43
# ... attempting to extract song_key:  1977-44
# ... attempting to extract song_key:  1977-45
# ... attempting to extract song_key:  1977-46
# ... attempting to extract song_key:  1977-47
# ... attempting to extract song_key:  1977-48
# ... attempting to extract song_key:  1977-49
# ... attempting to extract song_key:  1977-50
# ... attempting to extract song_key:  1977-51
# ... attempting to extract song_key:  1977-52
# ... attempting to extract song_key:  1977-53
# ... attempting to extract song_key:  1977-54
# ... attempting to extract song_key:  1977-56
# ... attempting to extract song_key:  1977-57
# ... attempting to extract song_key:  1977-58
# ... attempting to extract song_key:  1977-59
# ... attempting to extract song_key:  1977-60
# ... attempting to extract song_key:  1977-61
# ... attempting to extract song_key:  1977-62
# ... attempting to extract song_key:  1977-63
# ... attempting to extract song_key:  1977-64
# ... attempting to extract song_key:  1977-65
# ... attempting to extract song_key:  1977-66
# ... attempting to extract song_key:  1977-67
# ... attempting to extract song_key:  1977-68
# ... attempting to extract song_key:  1977-69
# ... attempting to extract song_key:  1977-70
# ... attempting to extract song_key:  1977-71
# 'NoneType' object is not callable
# ... attempting to extract song_key:  1977-72
# ... attempting to extract song_key:  1977-74
# ... attempting to extract song_key:  1977-75
# ... attempting to extract song_key:  1977-76
# ... attempting to extract song_key:  1977-77
# ... attempting to extract song_key:  1977-78
# ... attempting to extract song_key:  1977-79
# ... attempting to extract song_key:  1977-80
# ... attempting to extract song_key:  1977-81
# ... attempting to extract song_key:  1977-82
# ... attempting to extract song_key:  1977-83
# ... attempting to extract song_key:  1977-84
# ... attempting to extract song_key:  1977-85
# ... attempting to extract song_key:  1977-86
# ... attempting to extract song_key:  1977-87
# ... attempting to extract song_key:  1977-88
# ... attempting to extract song_key:  1977-89
# ... attempting to extract song_key:  1977-90
# ... attempting to extract song_key:  1977-91
# ... attempting to extract song_key:  1977-92
# ... attempting to extract song_key:  1977-93
# ... attempting to extract song_key:  1977-94
# ... attempting to extract song_key:  1977-95
# ... attempting to extract song_key:  1977-96
# ... attempting to extract song_key:  1977-97
# ... attempting to extract song_key:  1977-98
# ... attempting to extract song_key:  1978-1
# ... attempting to extract song_key:  1978-2
# ... attempting to extract song_key:  1978-3
# ... attempting to extract song_key:  1978-4
# ... attempting to extract song_key:  1978-5
# ... attempting to extract song_key:  1978-6
# 'NoneType' object is not callable
# ... attempting to extract song_key:  1978-7
# ... attempting to extract song_key:  1978-8
# ... attempting to extract song_key:  1978-9
# ... attempting to extract song_key:  1978-10
# ... attempting to extract song_key:  1978-11
# ... attempting to extract song_key:  1978-12
# ... attempting to extract song_key:  1978-13
# ... attempting to extract song_key:  1978-14
# ... attempting to extract song_key:  1978-15
# ... attempting to extract song_key:  1978-16
# ... attempting to extract song_key:  1978-17
# ... attempting to extract song_key:  1978-18
# ... attempting to extract song_key:  1978-19
# ... attempting to extract song_key:  1978-20
# ... attempting to extract song_key:  1978-21
# ... attempting to extract song_key:  1978-22
# ... attempting to extract song_key:  1978-23
# ... attempting to extract song_key:  1978-24
# ... attempting to extract song_key:  1978-26
# ... attempting to extract song_key:  1978-27
# ... attempting to extract song_key:  1978-28
# ... attempting to extract song_key:  1978-29
# ... attempting to extract song_key:  1978-30
# ... attempting to extract song_key:  1978-31
# ... attempting to extract song_key:  1978-32
# ... attempting to extract song_key:  1978-33
# ... attempting to extract song_key:  1978-34
# ... attempting to extract song_key:  1978-35
# ... attempting to extract song_key:  1978-36
# ... attempting to extract song_key:  1978-37
# ... attempting to extract song_key:  1978-38
# ... attempting to extract song_key:  1978-39
# ... attempting to extract song_key:  1978-40
# ... attempting to extract song_key:  1978-41
# ... attempting to extract song_key:  1978-42
# ... attempting to extract song_key:  1978-43
# ... attempting to extract song_key:  1978-44
# ... attempting to extract song_key:  1978-45
# ... attempting to extract song_key:  1978-46
# ... attempting to extract song_key:  1978-47
# ... attempting to extract song_key:  1978-48
# ... attempting to extract song_key:  1978-49
# ... attempting to extract song_key:  1978-50
# ... attempting to extract song_key:  1978-51
# ... attempting to extract song_key:  1978-53
# ... attempting to extract song_key:  1978-54
# ... attempting to extract song_key:  1978-55
# ... attempting to extract song_key:  1978-56
# ... attempting to extract song_key:  1978-57
# ... attempting to extract song_key:  1978-58
# ... attempting to extract song_key:  1978-59
# ... attempting to extract song_key:  1978-60
# ... attempting to extract song_key:  1978-61
# ... attempting to extract song_key:  1978-62
# ... attempting to extract song_key:  1978-63
# ... attempting to extract song_key:  1978-64
# ... attempting to extract song_key:  1978-65
# ... attempting to extract song_key:  1978-66
# ... attempting to extract song_key:  1978-67
# ... attempting to extract song_key:  1978-68
# ... attempting to extract song_key:  1978-69
# ... attempting to extract song_key:  1978-70
# ... attempting to extract song_key:  1978-71
# ... attempting to extract song_key:  1978-72
# ... attempting to extract song_key:  1978-73
# ... attempting to extract song_key:  1978-74
# ... attempting to extract song_key:  1978-75
# ... attempting to extract song_key:  1978-76
# ... attempting to extract song_key:  1978-77
# ... attempting to extract song_key:  1978-78
# ... attempting to extract song_key:  1978-80
# ... attempting to extract song_key:  1978-81
# ... attempting to extract song_key:  1978-82
# ... attempting to extract song_key:  1978-83
# ... attempting to extract song_key:  1978-84
# ... attempting to extract song_key:  1978-85
# ... attempting to extract song_key:  1978-86
# ... attempting to extract song_key:  1978-87
# ... attempting to extract song_key:  1978-88
# ... attempting to extract song_key:  1978-89
# ... attempting to extract song_key:  1978-90
# ... attempting to extract song_key:  1978-91
# ... attempting to extract song_key:  1978-92
# ... attempting to extract song_key:  1978-93
# ... attempting to extract song_key:  1978-94
# ... attempting to extract song_key:  1978-95
# ... attempting to extract song_key:  1978-96
# ... attempting to extract song_key:  1978-97
# ... attempting to extract song_key:  1978-98
# ... attempting to extract song_key:  1978-100
# ... attempting to extract song_key:  1979-1
# ... attempting to extract song_key:  1979-2
# ... attempting to extract song_key:  1979-3
# ... attempting to extract song_key:  1979-4
# ... attempting to extract song_key:  1979-5
# ... attempting to extract song_key:  1979-6
# ... attempting to extract song_key:  1979-7
# ... attempting to extract song_key:  1979-8
# ... attempting to extract song_key:  1979-9
# ... attempting to extract song_key:  1979-10
# ... attempting to extract song_key:  1979-11
# ... attempting to extract song_key:  1979-12
# ... attempting to extract song_key:  1979-13
# ... attempting to extract song_key:  1979-14
# ... attempting to extract song_key:  1979-15
# ... attempting to extract song_key:  1979-16
# ... attempting to extract song_key:  1979-17
# ... attempting to extract song_key:  1979-18
# ... attempting to extract song_key:  1979-19
# ... attempting to extract song_key:  1979-20
# ... attempting to extract song_key:  1979-21
# ... attempting to extract song_key:  1979-22
# ... attempting to extract song_key:  1979-23
# ... attempting to extract song_key:  1979-24
# ... attempting to extract song_key:  1979-25
# ... attempting to extract song_key:  1979-26
# ... attempting to extract song_key:  1979-27
# ... attempting to extract song_key:  1979-28
# ... attempting to extract song_key:  1979-29
# ... attempting to extract song_key:  1979-30
# ... attempting to extract song_key:  1979-31
# ... attempting to extract song_key:  1979-32
# ... attempting to extract song_key:  1979-33
# ... attempting to extract song_key:  1979-34
# ... attempting to extract song_key:  1979-35
# ... attempting to extract song_key:  1979-36
# ... attempting to extract song_key:  1979-37
# ... attempting to extract song_key:  1979-38
# ... attempting to extract song_key:  1979-39
# ... attempting to extract song_key:  1979-40
# ... attempting to extract song_key:  1979-41
# ... attempting to extract song_key:  1979-42
# ... attempting to extract song_key:  1979-43
# ... attempting to extract song_key:  1979-44
# ... attempting to extract song_key:  1979-45
# ... attempting to extract song_key:  1979-46
# ... attempting to extract song_key:  1979-47
# ... attempting to extract song_key:  1979-48
# ... attempting to extract song_key:  1979-49
# ... attempting to extract song_key:  1979-50
# ... attempting to extract song_key:  1979-51
# ... attempting to extract song_key:  1979-52
# ... attempting to extract song_key:  1979-53
# ... attempting to extract song_key:  1979-54
# ... attempting to extract song_key:  1979-55
# ... attempting to extract song_key:  1979-56
# ... attempting to extract song_key:  1979-57
# ... attempting to extract song_key:  1979-58
# ... attempting to extract song_key:  1979-59
# ... attempting to extract song_key:  1979-60
# ... attempting to extract song_key:  1979-61
# ... attempting to extract song_key:  1979-62
# ... attempting to extract song_key:  1979-63
# ... attempting to extract song_key:  1979-64
# ... attempting to extract song_key:  1979-65
# ... attempting to extract song_key:  1979-66
# ... attempting to extract song_key:  1979-67
# ... attempting to extract song_key:  1979-68
# ... attempting to extract song_key:  1979-69
# ... attempting to extract song_key:  1979-70
# ... attempting to extract song_key:  1979-71
# ... attempting to extract song_key:  1979-72
# ... attempting to extract song_key:  1979-73
# ... attempting to extract song_key:  1979-74
# ... attempting to extract song_key:  1979-75
# ... attempting to extract song_key:  1979-76
# ... attempting to extract song_key:  1979-77
# ... attempting to extract song_key:  1979-78
# ... attempting to extract song_key:  1979-79
# ... attempting to extract song_key:  1979-80
# ... attempting to extract song_key:  1979-81
# ... attempting to extract song_key:  1979-82
# ... attempting to extract song_key:  1979-83
# ... attempting to extract song_key:  1979-84
# ... attempting to extract song_key:  1979-85
# ... attempting to extract song_key:  1979-86
# ... attempting to extract song_key:  1979-87
# ... attempting to extract song_key:  1979-88
# ... attempting to extract song_key:  1979-89
# ... attempting to extract song_key:  1979-90
# ... attempting to extract song_key:  1979-91
# ... attempting to extract song_key:  1979-92
# ... attempting to extract song_key:  1979-93
# ... attempting to extract song_key:  1979-95
# ... attempting to extract song_key:  1979-96
# ... attempting to extract song_key:  1979-97
# ... attempting to extract song_key:  1979-98
# ... attempting to extract song_key:  1979-99
# ... attempting to extract song_key:  1979-100
# CPU times: user 53.8 s, sys: 1.18 s, total: 55 s
# Wall time: 58.3 s

# %%
print
print "how many new lyrics were extracted? ", len(new_refs70)
print "how many results were in the cache? ", len(cache_refs70)
print "how many issues were encountered? ", len(issues70)
# Out:
# how many new lyrics were extracted?  942
# how many results were in the cache?  0
# how many issues were encountered?  58

# %% [markdown]
# ##Process the Rest

# %%
print "execution start --> {}".format(time.strftime('%a, %d %b %Y %H:%M:%S', time.localtime()))
# Out:
# execution start --> Mon, 23 Nov 2015 17:07:25

# %%
# %%time
# process 70s
new_refs0, cache_refs0, issues0 = extractAvailableRawSongLyrics(lyricsdf[lyricsdf.decade != 1970])
# Out:
# ... attempting to extract song_key:  1980-1
# ... attempting to extract song_key:  1980-2
# ... attempting to extract song_key:  1980-3
# ... attempting to extract song_key:  1980-4
# ... attempting to extract song_key:  1980-5
# ... attempting to extract song_key:  1980-6
# ... attempting to extract song_key:  1980-7
# ... attempting to extract song_key:  1980-8
# ... attempting to extract song_key:  1980-9
# ... attempting to extract song_key:  1980-10
# ... attempting to extract song_key:  1980-11
# ... attempting to extract song_key:  1980-12
# ... attempting to extract song_key:  1980-13
# 'NoneType' object is not callable
# ... attempting to extract song_key:  1980-14
# ... attempting to extract song_key:  1980-15
# ... attempting to extract song_key:  1980-16
# ... attempting to extract song_key:  1980-17
# ... attempting to extract song_key:  1980-18
# ... attempting to extract song_key:  1980-19
# ... attempting to extract song_key:  1980-20
# ... attempting to extract song_key:  1980-21
# ... attempting to extract song_key:  1980-22
# ... attempting to extract song_key:  1980-23
# ... attempting to extract song_key:  1980-24
# ... attempting to extract song_key:  1980-25
# ... attempting to extract song_key:  1980-26
# ... attempting to extract song_key:  1980-27
# ... attempting to extract song_key:  1980-28
# ... attempting to extract song_key:  1980-29
# ... attempting to extract song_key:  1980-30
# ... attempting to extract song_key:  1980-31
# ... attempting to extract song_key:  1980-32
# ... attempting to extract song_key:  1980-33
# ... attempting to extract song_key:  1980-34
# ... attempting to extract song_key:  1980-35
# ... attempting to extract song_key:  1980-36
# ... attempting to extract song_key:  1980-37
# ... attempting to extract song_key:  1980-38
# ... attempting to extract song_key:  1980-39
# ... attempting to extract song_key:  1980-40
# ... attempting to extract song_key:  1980-41
# ... attempting to extract song_key:  1980-43
# ... attempting to extract song_key:  1980-44
# ... attempting to extract song_key:  1980-45
# ... attempting to extract song_key:  1980-46
# ... attempting to extract song_key:  1980-47
# ... attempting to extract song_key:  1980-48
# ... attempting to extract song_key:  1980-49
# ... attempting to extract song_key:  1980-50
# ... attempting to extract song_key:  1980-52
# ... attempting to extract song_key:  1980-53
# ... attempting to extract song_key:  1980-54
# ... attempting to extract song_key:  1980-55
# ... attempting to extract song_key:  1980-56
# ... attempting to extract song_key:  1980-57
# ... attempting to extract song_key:  1980-58
# ... attempting to extract song_key:  1980-59
# ... attempting to extract song_key:  1980-60
# ... attempting to extract song_key:  1980-61
# ... attempting to extract song_key:  1980-62
# ... attempting to extract song_key:  1980-63
# ... attempting to extract song_key:  1980-64
# ... attempting to extract song_key:  1980-65
# ... attempting to extract song_key:  1980-66
# ... attempting to extract song_key:  1980-67
# ... attempting to extract song_key:  1980-68
# ... attempting to extract song_key:  1980-69
# ... attempting to extract song_key:  1980-70
# ... attempting to extract song_key:  1980-71
# ... attempting to extract song_key:  1980-73
# ... attempting to extract song_key:  1980-74
# ... attempting to extract song_key:  1980-75
# ... attempting to extract song_key:  1980-76
# ... attempting to extract song_key:  1980-78
# ... attempting to extract song_key:  1980-79
# ... attempting to extract song_key:  1980-80
# ... attempting to extract song_key:  1980-81
# ... attempting to extract song_key:  1980-82
# ... attempting to extract song_key:  1980-83
# ... attempting to extract song_key:  1980-85
# ... attempting to extract song_key:  1980-86
# ... attempting to extract song_key:  1980-87
# ... attempting to extract song_key:  1980-88
# ... attempting to extract song_key:  1980-89
# ... attempting to extract song_key:  1980-90
# ... attempting to extract song_key:  1980-91
# ... attempting to extract song_key:  1980-92
# ... attempting to extract song_key:  1980-93
# ... attempting to extract song_key:  1980-94
# ... attempting to extract song_key:  1980-95
# ... attempting to extract song_key:  1980-96
# ... attempting to extract song_key:  1980-97
# ... attempting to extract song_key:  1980-98
# ... attempting to extract song_key:  1980-99
# ... attempting to extract song_key:  1980-100
# ... attempting to extract song_key:  1981-1
# ... attempting to extract song_key:  1981-2
# ... attempting to extract song_key:  1981-3
# ... attempting to extract song_key:  1981-4
# ... attempting to extract song_key:  1981-5
# ... attempting to extract song_key:  1981-6
# ... attempting to extract song_key:  1981-7
# ... attempting to extract song_key:  1981-8
# ... attempting to extract song_key:  1981-9
# ... attempting to extract song_key:  1981-10
# ... attempting to extract song_key:  1981-11
# ... attempting to extract song_key:  1981-12
# ... attempting to extract song_key:  1981-13
# ... attempting to extract song_key:  1981-14
# ... attempting to extract song_key:  1981-15
# ... attempting to extract song_key:  1981-16
# ... attempting to extract song_key:  1981-17
# ... attempting to extract song_key:  1981-18
# ... attempting to extract song_key:  1981-19
# ... attempting to extract song_key:  1981-20
# ... attempting to extract song_key:  1981-21
# ... attempting to extract song_key:  1981-22
# ... attempting to extract song_key:  1981-23
# ... attempting to extract song_key:  1981-24
# ... attempting to extract song_key:  1981-25
# ... attempting to extract song_key:  1981-26
# ... attempting to extract song_key:  1981-27
# ... attempting to extract song_key:  1981-28
# ... attempting to extract song_key:  1981-29
# ... attempting to extract song_key:  1981-30
# ... attempting to extract song_key:  1981-31
# ... attempting to extract song_key:  1981-32
# ... attempting to extract song_key:  1981-33
# ... attempting to extract song_key:  1981-34
# ... attempting to extract song_key:  1981-35
# ... attempting to extract song_key:  1981-37
# ... attempting to extract song_key:  1981-38
# ... attempting to extract song_key:  1981-39
# ... attempting to extract song_key:  1981-40
# ... attempting to extract song_key:  1981-41
# ... attempting to extract song_key:  1981-42
# ... attempting to extract song_key:  1981-43
# ... attempting to extract song_key:  1981-44
# ... attempting to extract song_key:  1981-45
# ... attempting to extract song_key:  1981-46
# ... attempting to extract song_key:  1981-47
# ... attempting to extract song_key:  1981-48
# ... attempting to extract song_key:  1981-49
# ... attempting to extract song_key:  1981-50
# ... attempting to extract song_key:  1981-51
# ... attempting to extract song_key:  1981-52
# ... attempting to extract song_key:  1981-53
# ... attempting to extract song_key:  1981-54
# ... attempting to extract song_key:  1981-55
# ... attempting to extract song_key:  1981-56
# ... attempting to extract song_key:  1981-57
# ... attempting to extract song_key:  1981-58
# ... attempting to extract song_key:  1981-59
# ... attempting to extract song_key:  1981-60
# ... attempting to extract song_key:  1981-61
# ... attempting to extract song_key:  1981-62
# ... attempting to extract song_key:  1981-63
# ... attempting to extract song_key:  1981-64
# ... attempting to extract song_key:  1981-65
# ... attempting to extract song_key:  1981-66
# ... attempting to extract song_key:  1981-67
# ... attempting to extract song_key:  1981-68
# ... attempting to extract song_key:  1981-69
# ... attempting to extract song_key:  1981-70
# ... attempting to extract song_key:  1981-71
# ... attempting to extract song_key:  1981-72
# ... attempting to extract song_key:  1981-73
# ... attempting to extract song_key:  1981-74
# ... attempting to extract song_key:  1981-75
# ... attempting to extract song_key:  1981-76
# ... attempting to extract song_key:  1981-77
# ... attempting to extract song_key:  1981-78
# ... attempting to extract song_key:  1981-79
# ... attempting to extract song_key:  1981-80
# ... attempting to extract song_key:  1981-81
# ... attempting to extract song_key:  1981-82
# ... attempting to extract song_key:  1981-83
# ... attempting to extract song_key:  1981-84
# ... attempting to extract song_key:  1981-85
# ... attempting to extract song_key:  1981-86
# ... attempting to extract song_key:  1981-87
# ... attempting to extract song_key:  1981-88
# ... attempting to extract song_key:  1981-89
# ... attempting to extract song_key:  1981-90
# ... attempting to extract song_key:  1981-91
# ... attempting to extract song_key:  1981-92
# ... attempting to extract song_key:  1981-93
# ... attempting to extract song_key:  1981-94
# ... attempting to extract song_key:  1981-95
# ... attempting to extract song_key:  1981-96
# ... attempting to extract song_key:  1981-97
# ... attempting to extract song_key:  1981-98
# ... attempting to extract song_key:  1981-99
# ... attempting to extract song_key:  1981-100
# ... attempting to extract song_key:  1982-1
# ... attempting to extract song_key:  1982-2
# ... attempting to extract song_key:  1982-3
# ... attempting to extract song_key:  1982-4
# ... attempting to extract song_key:  1982-6
# ... attempting to extract song_key:  1982-7
# ... attempting to extract song_key:  1982-8
# ... attempting to extract song_key:  1982-9
# ... attempting to extract song_key:  1982-10
# ... attempting to extract song_key:  1982-11
# ... attempting to extract song_key:  1982-12
# ... attempting to extract song_key:  1982-13
# ... attempting to extract song_key:  1982-14
# ... attempting to extract song_key:  1982-15
# ... attempting to extract song_key:  1982-16
# ... attempting to extract song_key:  1982-17
# ... attempting to extract song_key:  1982-18
# ... attempting to extract song_key:  1982-19
# ... attempting to extract song_key:  1982-20
# ... attempting to extract song_key:  1982-21
# ... attempting to extract song_key:  1982-22
# ... attempting to extract song_key:  1982-23
# ... attempting to extract song_key:  1982-24
# ... attempting to extract song_key:  1982-25
# ... attempting to extract song_key:  1982-26
# ... attempting to extract song_key:  1982-27
# ... attempting to extract song_key:  1982-28
# ... attempting to extract song_key:  1982-29
# ... attempting to extract song_key:  1982-30
# ... attempting to extract song_key:  1982-31
# ... attempting to extract song_key:  1982-32
# ... attempting to extract song_key:  1982-33
# ... attempting to extract song_key:  1982-34
# ... attempting to extract song_key:  1982-35
# ... attempting to extract song_key:  1982-36
# ... attempting to extract song_key:  1982-37
# ... attempting to extract song_key:  1982-38
# ... attempting to extract song_key:  1982-39
# ... attempting to extract song_key:  1982-40
# ... attempting to extract song_key:  1982-41
# ... attempting to extract song_key:  1982-42
# ... attempting to extract song_key:  1982-43
# ... attempting to extract song_key:  1982-44
# ... attempting to extract song_key:  1982-45
# ... attempting to extract song_key:  1982-46
# ... attempting to extract song_key:  1982-47
# ... attempting to extract song_key:  1982-48
# ... attempting to extract song_key:  1982-49
# ... attempting to extract song_key:  1982-50
# ... attempting to extract song_key:  1982-51
# ... attempting to extract song_key:  1982-52
# ... attempting to extract song_key:  1982-53
# ... attempting to extract song_key:  1982-54
# ... attempting to extract song_key:  1982-55
# ... attempting to extract song_key:  1982-56
# ... attempting to extract song_key:  1982-57
# ... attempting to extract song_key:  1982-58
# ... attempting to extract song_key:  1982-59
# ... attempting to extract song_key:  1982-60
# ... attempting to extract song_key:  1982-61
# ... attempting to extract song_key:  1982-62
# ... attempting to extract song_key:  1982-63
# ... attempting to extract song_key:  1982-64
# ... attempting to extract song_key:  1982-65
# ... attempting to extract song_key:  1982-66
# ... attempting to extract song_key:  1982-67
# ... attempting to extract song_key:  1982-68
# ... attempting to extract song_key:  1982-69
# ... attempting to extract song_key:  1982-70
# ... attempting to extract song_key:  1982-71
# ... attempting to extract song_key:  1982-72
# ... attempting to extract song_key:  1982-73
# ... attempting to extract song_key:  1982-74
# ... attempting to extract song_key:  1982-75
# ... attempting to extract song_key:  1982-76
# ... attempting to extract song_key:  1982-77
# ... attempting to extract song_key:  1982-78
# ... attempting to extract song_key:  1982-79
# ... attempting to extract song_key:  1982-80
# ... attempting to extract song_key:  1982-81
# ... attempting to extract song_key:  1982-82
# ... attempting to extract song_key:  1982-83
# ... attempting to extract song_key:  1982-84
# ... attempting to extract song_key:  1982-85
# ... attempting to extract song_key:  1982-86
# ... attempting to extract song_key:  1982-87
# ... attempting to extract song_key:  1982-88
# ... attempting to extract song_key:  1982-89
# ... attempting to extract song_key:  1982-90
# ... attempting to extract song_key:  1982-91
# ... attempting to extract song_key:  1982-92
# ... attempting to extract song_key:  1982-93
# ... attempting to extract song_key:  1982-94
# ... attempting to extract song_key:  1982-95
# ... attempting to extract song_key:  1982-96
# ... attempting to extract song_key:  1982-97
# ... attempting to extract song_key:  1982-98
# ... attempting to extract song_key:  1982-99
# ... attempting to extract song_key:  1982-100
# ... attempting to extract song_key:  1983-1
# ... attempting to extract song_key:  1983-2
# ... attempting to extract song_key:  1983-3
# ... attempting to extract song_key:  1983-4
# ... attempting to extract song_key:  1983-5
# ... attempting to extract song_key:  1983-6
# ... attempting to extract song_key:  1983-7
# ... attempting to extract song_key:  1983-8
# ... attempting to extract song_key:  1983-9
# ... attempting to extract song_key:  1983-10
# ... attempting to extract song_key:  1983-11
# ... attempting to extract song_key:  1983-12
# ... attempting to extract song_key:  1983-13
# ... attempting to extract song_key:  1983-15
# ... attempting to extract song_key:  1983-16
# ... attempting to extract song_key:  1983-17
# ... attempting to extract song_key:  1983-18
# ... attempting to extract song_key:  1983-19
# ... attempting to extract song_key:  1983-20
# ... attempting to extract song_key:  1983-21
# ... attempting to extract song_key:  1983-22
# ... attempting to extract song_key:  1983-23
# ... attempting to extract song_key:  1983-24
# ... attempting to extract song_key:  1983-25
# ... attempting to extract song_key:  1983-26
# ... attempting to extract song_key:  1983-27
# ... attempting to extract song_key:  1983-28
# ... attempting to extract song_key:  1983-29
# ... attempting to extract song_key:  1983-30
# ... attempting to extract song_key:  1983-31
# ... attempting to extract song_key:  1983-32
# ... attempting to extract song_key:  1983-33
# ... attempting to extract song_key:  1983-34
# ... attempting to extract song_key:  1983-35
# ... attempting to extract song_key:  1983-36
# ... attempting to extract song_key:  1983-37
# ... attempting to extract song_key:  1983-38
# ... attempting to extract song_key:  1983-39
# ... attempting to extract song_key:  1983-40
# ... attempting to extract song_key:  1983-41
# ... attempting to extract song_key:  1983-42
# ... attempting to extract song_key:  1983-43
# ... attempting to extract song_key:  1983-44
# ... attempting to extract song_key:  1983-45
# ... attempting to extract song_key:  1983-46
# ... attempting to extract song_key:  1983-47
# ... attempting to extract song_key:  1983-48
# ... attempting to extract song_key:  1983-49
# ... attempting to extract song_key:  1983-50
# ... attempting to extract song_key:  1983-51
# 'NoneType' object is not callable
# ... attempting to extract song_key:  1983-52
# ... attempting to extract song_key:  1983-53
# ... attempting to extract song_key:  1983-54
# ... attempting to extract song_key:  1983-55
# ... attempting to extract song_key:  1983-56
# ... attempting to extract song_key:  1983-57
# ... attempting to extract song_key:  1983-58
# ... attempting to extract song_key:  1983-59
# ... attempting to extract song_key:  1983-60
# ... attempting to extract song_key:  1983-61
# ... attempting to extract song_key:  1983-62
# ... attempting to extract song_key:  1983-63
# ... attempting to extract song_key:  1983-64
# ... attempting to extract song_key:  1983-65
# ... attempting to extract song_key:  1983-66
# ... attempting to extract song_key:  1983-67
# ... attempting to extract song_key:  1983-68
# ... attempting to extract song_key:  1983-69
# ... attempting to extract song_key:  1983-70
# ... attempting to extract song_key:  1983-71
# ... attempting to extract song_key:  1983-72
# ... attempting to extract song_key:  1983-73
# ... attempting to extract song_key:  1983-74
# ... attempting to extract song_key:  1983-75
# ... attempting to extract song_key:  1983-76
# ... attempting to extract song_key:  1983-77
# ... attempting to extract song_key:  1983-78
# ... attempting to extract song_key:  1983-79
# ... attempting to extract song_key:  1983-80
# ... attempting to extract song_key:  1983-81
# ... attempting to extract song_key:  1983-82
# ... attempting to extract song_key:  1983-83
# ... attempting to extract song_key:  1983-84
# ... attempting to extract song_key:  1983-85
# ... attempting to extract song_key:  1983-86
# ... attempting to extract song_key:  1983-87
# ... attempting to extract song_key:  1983-88
# ... attempting to extract song_key:  1983-89
# ... attempting to extract song_key:  1983-90
# ... attempting to extract song_key:  1983-91
# ... attempting to extract song_key:  1983-92
# ... attempting to extract song_key:  1983-93
# ... attempting to extract song_key:  1983-94
# ... attempting to extract song_key:  1983-95
# ... attempting to extract song_key:  1983-96
# ... attempting to extract song_key:  1983-97
# ... attempting to extract song_key:  1983-98
# ... attempting to extract song_key:  1983-99
# ... attempting to extract song_key:  1983-100
# ... attempting to extract song_key:  1984-1
# ... attempting to extract song_key:  1984-2
# ... attempting to extract song_key:  1984-3
# ... attempting to extract song_key:  1984-4
# ... attempting to extract song_key:  1984-5
# ... attempting to extract song_key:  1984-6
# ... attempting to extract song_key:  1984-7
# ... attempting to extract song_key:  1984-8
# ... attempting to extract song_key:  1984-9
# ... attempting to extract song_key:  1984-10
# ... attempting to extract song_key:  1984-11
# ... attempting to extract song_key:  1984-12
# ... attempting to extract song_key:  1984-13
# ... attempting to extract song_key:  1984-14
# ... attempting to extract song_key:  1984-15
# ... attempting to extract song_key:  1984-16
# ... attempting to extract song_key:  1984-17
# ... attempting to extract song_key:  1984-18
# ... attempting to extract song_key:  1984-19
# ... attempting to extract song_key:  1984-20
# ... attempting to extract song_key:  1984-21
# ... attempting to extract song_key:  1984-22
# ... attempting to extract song_key:  1984-23
# ... attempting to extract song_key:  1984-24
# ... attempting to extract song_key:  1984-25
# ... attempting to extract song_key:  1984-26
# ... attempting to extract song_key:  1984-27
# ... attempting to extract song_key:  1984-28
# ... attempting to extract song_key:  1984-29
# ... attempting to extract song_key:  1984-30
# ... attempting to extract song_key:  1984-31
# ... attempting to extract song_key:  1984-32
# ... attempting to extract song_key:  1984-33
# ... attempting to extract song_key:  1984-34
# ... attempting to extract song_key:  1984-35
# ... attempting to extract song_key:  1984-36
# ... attempting to extract song_key:  1984-37
# ... attempting to extract song_key:  1984-38
# ... attempting to extract song_key:  1984-39
# ... attempting to extract song_key:  1984-40
# ... attempting to extract song_key:  1984-41
# ... attempting to extract song_key:  1984-42
# ... attempting to extract song_key:  1984-43
# ... attempting to extract song_key:  1984-44
# ... attempting to extract song_key:  1984-45
# ... attempting to extract song_key:  1984-46
# ... attempting to extract song_key:  1984-47
# ... attempting to extract song_key:  1984-48
# ... attempting to extract song_key:  1984-49
# ... attempting to extract song_key:  1984-50
# ... attempting to extract song_key:  1984-51
# ... attempting to extract song_key:  1984-52
# ... attempting to extract song_key:  1984-53
# ... attempting to extract song_key:  1984-54
# ... attempting to extract song_key:  1984-55
# ... attempting to extract song_key:  1984-56
# ... attempting to extract song_key:  1984-57
# ... attempting to extract song_key:  1984-58
# ... attempting to extract song_key:  1984-60
# ... attempting to extract song_key:  1984-61
# ... attempting to extract song_key:  1984-62
# ... attempting to extract song_key:  1984-63
# ... attempting to extract song_key:  1984-64
# ... attempting to extract song_key:  1984-65
# ... attempting to extract song_key:  1984-66
# ... attempting to extract song_key:  1984-67
# ... attempting to extract song_key:  1984-68
# ... attempting to extract song_key:  1984-69
# ... attempting to extract song_key:  1984-70
# ... attempting to extract song_key:  1984-71
# ... attempting to extract song_key:  1984-72
# ... attempting to extract song_key:  1984-73
# ... attempting to extract song_key:  1984-74
# ... attempting to extract song_key:  1984-75
# ... attempting to extract song_key:  1984-76
# ... attempting to extract song_key:  1984-77
# ... attempting to extract song_key:  1984-78
# ... attempting to extract song_key:  1984-79
# ... attempting to extract song_key:  1984-81
# ... attempting to extract song_key:  1984-82
# ... attempting to extract song_key:  1984-83
# ... attempting to extract song_key:  1984-84
# ... attempting to extract song_key:  1984-85
# ... attempting to extract song_key:  1984-86
# ... attempting to extract song_key:  1984-87
# ... attempting to extract song_key:  1984-88
# ... attempting to extract song_key:  1984-89
# ... attempting to extract song_key:  1984-90
# ... attempting to extract song_key:  1984-91
# ... attempting to extract song_key:  1984-92
# ... attempting to extract song_key:  1984-93
# ... attempting to extract song_key:  1984-95
# ... attempting to extract song_key:  1984-96
# ... attempting to extract song_key:  1984-97
# ... attempting to extract song_key:  1984-98
# ... attempting to extract song_key:  1984-99
# ... attempting to extract song_key:  1984-100
# ... attempting to extract song_key:  1985-1
# ... attempting to extract song_key:  1985-2
# ... attempting to extract song_key:  1985-3
# ... attempting to extract song_key:  1985-4
# ... attempting to extract song_key:  1985-5
# ... attempting to extract song_key:  1985-6
# ... attempting to extract song_key:  1985-7
# ... attempting to extract song_key:  1985-8
# ... attempting to extract song_key:  1985-9
# ... attempting to extract song_key:  1985-10
# ... attempting to extract song_key:  1985-11
# ... attempting to extract song_key:  1985-12
# ... attempting to extract song_key:  1985-13
# ... attempting to extract song_key:  1985-14
# ... attempting to extract song_key:  1985-15
# ... attempting to extract song_key:  1985-16
# ... attempting to extract song_key:  1985-17
# ... attempting to extract song_key:  1985-18
# ... attempting to extract song_key:  1985-19
# ... attempting to extract song_key:  1985-20
# ... attempting to extract song_key:  1985-21
# ... attempting to extract song_key:  1985-22
# ... attempting to extract song_key:  1985-23
# ... attempting to extract song_key:  1985-24
# ... attempting to extract song_key:  1985-25
# ... attempting to extract song_key:  1985-26
# ... attempting to extract song_key:  1985-27
# ... attempting to extract song_key:  1985-28
# ... attempting to extract song_key:  1985-29
# ... attempting to extract song_key:  1985-30
# ... attempting to extract song_key:  1985-31
# ... attempting to extract song_key:  1985-32
# ... attempting to extract song_key:  1985-33
# ... attempting to extract song_key:  1985-34
# ... attempting to extract song_key:  1985-35
# ... attempting to extract song_key:  1985-36
# ... attempting to extract song_key:  1985-37
# ... attempting to extract song_key:  1985-38
# ... attempting to extract song_key:  1985-39
# ... attempting to extract song_key:  1985-40
# ... attempting to extract song_key:  1985-41
# ... attempting to extract song_key:  1985-42
# ... attempting to extract song_key:  1985-43
# ... attempting to extract song_key:  1985-44
# ... attempting to extract song_key:  1985-45
# ... attempting to extract song_key:  1985-46
# ... attempting to extract song_key:  1985-47
# ... attempting to extract song_key:  1985-48
# ... attempting to extract song_key:  1985-49
# ... attempting to extract song_key:  1985-50
# ... attempting to extract song_key:  1985-51
# ... attempting to extract song_key:  1985-52
# ... attempting to extract song_key:  1985-53
# ... attempting to extract song_key:  1985-54
# ... attempting to extract song_key:  1985-55
# ... attempting to extract song_key:  1985-56
# ... attempting to extract song_key:  1985-57
# ... attempting to extract song_key:  1985-58
# ... attempting to extract song_key:  1985-59
# ... attempting to extract song_key:  1985-60
# ... attempting to extract song_key:  1985-61
# ... attempting to extract song_key:  1985-62
# ... attempting to extract song_key:  1985-63
# ... attempting to extract song_key:  1985-64
# ... attempting to extract song_key:  1985-65
# ... attempting to extract song_key:  1985-66
# ... attempting to extract song_key:  1985-67
# ... attempting to extract song_key:  1985-68
# ... attempting to extract song_key:  1985-69
# ... attempting to extract song_key:  1985-70
# ... attempting to extract song_key:  1985-71
# ... attempting to extract song_key:  1985-72
# ... attempting to extract song_key:  1985-73
# ... attempting to extract song_key:  1985-74
# ... attempting to extract song_key:  1985-75
# ... attempting to extract song_key:  1985-76
# ... attempting to extract song_key:  1985-77
# ... attempting to extract song_key:  1985-78
# ... attempting to extract song_key:  1985-79
# ... attempting to extract song_key:  1985-80
# ... attempting to extract song_key:  1985-81
# ... attempting to extract song_key:  1985-82
# ... attempting to extract song_key:  1985-83
# ... attempting to extract song_key:  1985-84
# ... attempting to extract song_key:  1985-85
# ... attempting to extract song_key:  1985-86
# ... attempting to extract song_key:  1985-87
# ... attempting to extract song_key:  1985-88
# ... attempting to extract song_key:  1985-89
# ... attempting to extract song_key:  1985-90
# ... attempting to extract song_key:  1985-91
# ... attempting to extract song_key:  1985-92
# ... attempting to extract song_key:  1985-93
# ... attempting to extract song_key:  1985-94
# ... attempting to extract song_key:  1985-95
# ... attempting to extract song_key:  1985-96
# ... attempting to extract song_key:  1985-97
# ... attempting to extract song_key:  1985-98
# ... attempting to extract song_key:  1985-99
# ... attempting to extract song_key:  1985-100
# ... attempting to extract song_key:  1986-1
# ... attempting to extract song_key:  1986-2
# ... attempting to extract song_key:  1986-3
# ... attempting to extract song_key:  1986-4
# ... attempting to extract song_key:  1986-5
# ... attempting to extract song_key:  1986-6
# ... attempting to extract song_key:  1986-7
# ... attempting to extract song_key:  1986-8
# ... attempting to extract song_key:  1986-9
# ... attempting to extract song_key:  1986-10
# ... attempting to extract song_key:  1986-11
# ... attempting to extract song_key:  1986-12
# ... attempting to extract song_key:  1986-13
# ... attempting to extract song_key:  1986-14
# ... attempting to extract song_key:  1986-15
# ... attempting to extract song_key:  1986-16
# ... attempting to extract song_key:  1986-17
# ... attempting to extract song_key:  1986-18
# ... attempting to extract song_key:  1986-19
# ... attempting to extract song_key:  1986-20
# ... attempting to extract song_key:  1986-21
# ... attempting to extract song_key:  1986-22
# ... attempting to extract song_key:  1986-23
# ... attempting to extract song_key:  1986-24
# ... attempting to extract song_key:  1986-25
# ... attempting to extract song_key:  1986-26
# ... attempting to extract song_key:  1986-27
# ... attempting to extract song_key:  1986-28
# ... attempting to extract song_key:  1986-29
# ... attempting to extract song_key:  1986-30
# ... attempting to extract song_key:  1986-31
# ... attempting to extract song_key:  1986-32
# ... attempting to extract song_key:  1986-33
# ... attempting to extract song_key:  1986-34
# ... attempting to extract song_key:  1986-35
# ... attempting to extract song_key:  1986-36
# ... attempting to extract song_key:  1986-37
# ... attempting to extract song_key:  1986-38
# ... attempting to extract song_key:  1986-39
# ... attempting to extract song_key:  1986-40
# ... attempting to extract song_key:  1986-41
# ... attempting to extract song_key:  1986-42
# ... attempting to extract song_key:  1986-43
# ... attempting to extract song_key:  1986-44
# ... attempting to extract song_key:  1986-45
# ... attempting to extract song_key:  1986-46
# ... attempting to extract song_key:  1986-47
# ... attempting to extract song_key:  1986-48
# ... attempting to extract song_key:  1986-49
# ... attempting to extract song_key:  1986-50
# ... attempting to extract song_key:  1986-51
# ... attempting to extract song_key:  1986-52
# ... attempting to extract song_key:  1986-53
# ... attempting to extract song_key:  1986-54
# ... attempting to extract song_key:  1986-55
# ... attempting to extract song_key:  1986-56
# ... attempting to extract song_key:  1986-57
# ... attempting to extract song_key:  1986-58
# ... attempting to extract song_key:  1986-59
# ... attempting to extract song_key:  1986-60
# ... attempting to extract song_key:  1986-61
# ... attempting to extract song_key:  1986-62
# ... attempting to extract song_key:  1986-63
# ... attempting to extract song_key:  1986-64
# ... attempting to extract song_key:  1986-65
# ... attempting to extract song_key:  1986-66
# ... attempting to extract song_key:  1986-67
# ... attempting to extract song_key:  1986-68
# ... attempting to extract song_key:  1986-69
# ... attempting to extract song_key:  1986-70
# ... attempting to extract song_key:  1986-71
# ... attempting to extract song_key:  1986-72
# ... attempting to extract song_key:  1986-73
# ... attempting to extract song_key:  1986-74
# ... attempting to extract song_key:  1986-75
# ... attempting to extract song_key:  1986-76
# ... attempting to extract song_key:  1986-77
# ... attempting to extract song_key:  1986-78
# ... attempting to extract song_key:  1986-79
# ... attempting to extract song_key:  1986-80
# ... attempting to extract song_key:  1986-81
# ... attempting to extract song_key:  1986-82
# ... attempting to extract song_key:  1986-83
# ... attempting to extract song_key:  1986-84
# ... attempting to extract song_key:  1986-85
# ... attempting to extract song_key:  1986-86
# ... attempting to extract song_key:  1986-87
# ... attempting to extract song_key:  1986-88
# ... attempting to extract song_key:  1986-90
# ... attempting to extract song_key:  1986-91
# ... attempting to extract song_key:  1986-92
# ... attempting to extract song_key:  1986-93
# ... attempting to extract song_key:  1986-94
# ... attempting to extract song_key:  1986-95
# ... attempting to extract song_key:  1986-96
# ... attempting to extract song_key:  1986-97
# ... attempting to extract song_key:  1986-98
# ... attempting to extract song_key:  1986-99
# ... attempting to extract song_key:  1986-100
# ... attempting to extract song_key:  1987-1
# ... attempting to extract song_key:  1987-2
# ... attempting to extract song_key:  1987-3
# ... attempting to extract song_key:  1987-4
# ... attempting to extract song_key:  1987-5
# ... attempting to extract song_key:  1987-6
# ... attempting to extract song_key:  1987-7
# ... attempting to extract song_key:  1987-8
# ... attempting to extract song_key:  1987-9
# ... attempting to extract song_key:  1987-10
# ... attempting to extract song_key:  1987-11
# ... attempting to extract song_key:  1987-12
# ... attempting to extract song_key:  1987-13
# ... attempting to extract song_key:  1987-14
# ... attempting to extract song_key:  1987-15
# ... attempting to extract song_key:  1987-16
# ... attempting to extract song_key:  1987-17
# ... attempting to extract song_key:  1987-18
# ... attempting to extract song_key:  1987-19
# ... attempting to extract song_key:  1987-20
# ... attempting to extract song_key:  1987-21
# ... attempting to extract song_key:  1987-22
# ... attempting to extract song_key:  1987-23
# ... attempting to extract song_key:  1987-24
# ... attempting to extract song_key:  1987-25
# ... attempting to extract song_key:  1987-26
# ... attempting to extract song_key:  1987-27
# ... attempting to extract song_key:  1987-28
# ... attempting to extract song_key:  1987-29
# ... attempting to extract song_key:  1987-30
# ... attempting to extract song_key:  1987-31
# ... attempting to extract song_key:  1987-32
# ... attempting to extract song_key:  1987-33
# ... attempting to extract song_key:  1987-34
# ... attempting to extract song_key:  1987-35
# ... attempting to extract song_key:  1987-36
# ... attempting to extract song_key:  1987-37
# ... attempting to extract song_key:  1987-38
# ... attempting to extract song_key:  1987-39
# ... attempting to extract song_key:  1987-40
# ... attempting to extract song_key:  1987-41
# ... attempting to extract song_key:  1987-42
# ... attempting to extract song_key:  1987-43
# ... attempting to extract song_key:  1987-44
# ... attempting to extract song_key:  1987-45
# ... attempting to extract song_key:  1987-46
# ... attempting to extract song_key:  1987-47
# ... attempting to extract song_key:  1987-48
# ... attempting to extract song_key:  1987-49
# ... attempting to extract song_key:  1987-50
# ... attempting to extract song_key:  1987-51
# ... attempting to extract song_key:  1987-52
# ... attempting to extract song_key:  1987-53
# ... attempting to extract song_key:  1987-54
# ... attempting to extract song_key:  1987-55
# ... attempting to extract song_key:  1987-56
# ... attempting to extract song_key:  1987-57
# ... attempting to extract song_key:  1987-58
# ... attempting to extract song_key:  1987-59
# ... attempting to extract song_key:  1987-60
# ... attempting to extract song_key:  1987-61
# ... attempting to extract song_key:  1987-62
# ... attempting to extract song_key:  1987-63
# ... attempting to extract song_key:  1987-64
# ... attempting to extract song_key:  1987-65
# ... attempting to extract song_key:  1987-66
# ... attempting to extract song_key:  1987-67
# ... attempting to extract song_key:  1987-68
# ... attempting to extract song_key:  1987-69
# ... attempting to extract song_key:  1987-70
# ... attempting to extract song_key:  1987-71
# ... attempting to extract song_key:  1987-72
# ... attempting to extract song_key:  1987-73
# ... attempting to extract song_key:  1987-74
# ... attempting to extract song_key:  1987-75
# ... attempting to extract song_key:  1987-76
# ... attempting to extract song_key:  1987-77
# ... attempting to extract song_key:  1987-78
# ... attempting to extract song_key:  1987-79
# ... attempting to extract song_key:  1987-80
# ... attempting to extract song_key:  1987-81
# ... attempting to extract song_key:  1987-82
# ... attempting to extract song_key:  1987-83
# ... attempting to extract song_key:  1987-84
# ... attempting to extract song_key:  1987-85
# ... attempting to extract song_key:  1987-86
# ... attempting to extract song_key:  1987-87
# ... attempting to extract song_key:  1987-88
# ... attempting to extract song_key:  1987-89
# ... attempting to extract song_key:  1987-90
# ... attempting to extract song_key:  1987-91
# ... attempting to extract song_key:  1987-92
# ... attempting to extract song_key:  1987-93
# ... attempting to extract song_key:  1987-94
# ... attempting to extract song_key:  1987-95
# ... attempting to extract song_key:  1987-96
# ... attempting to extract song_key:  1987-97
# ... attempting to extract song_key:  1987-98
# ... attempting to extract song_key:  1987-99
# ... attempting to extract song_key:  1987-100
# ... attempting to extract song_key:  1988-1
# ... attempting to extract song_key:  1988-2
# ... attempting to extract song_key:  1988-3
# ... attempting to extract song_key:  1988-4
# ... attempting to extract song_key:  1988-5
# ... attempting to extract song_key:  1988-6
# ... attempting to extract song_key:  1988-7
# ... attempting to extract song_key:  1988-8
# ... attempting to extract song_key:  1988-9
# ... attempting to extract song_key:  1988-10
# ... attempting to extract song_key:  1988-11
# ... attempting to extract song_key:  1988-12
# ... attempting to extract song_key:  1988-13
# ... attempting to extract song_key:  1988-14
# ... attempting to extract song_key:  1988-15
# ... attempting to extract song_key:  1988-16
# ... attempting to extract song_key:  1988-17
# ... attempting to extract song_key:  1988-18
# ... attempting to extract song_key:  1988-19
# ... attempting to extract song_key:  1988-20
# ... attempting to extract song_key:  1988-21
# ... attempting to extract song_key:  1988-22
# ... attempting to extract song_key:  1988-23
# ... attempting to extract song_key:  1988-24
# ... attempting to extract song_key:  1988-25
# ... attempting to extract song_key:  1988-26
# ... attempting to extract song_key:  1988-27
# ... attempting to extract song_key:  1988-28
# ... attempting to extract song_key:  1988-29
# ... attempting to extract song_key:  1988-30
# ... attempting to extract song_key:  1988-31
# ... attempting to extract song_key:  1988-32
# ... attempting to extract song_key:  1988-33
# ... attempting to extract song_key:  1988-34
# ... attempting to extract song_key:  1988-35
# ... attempting to extract song_key:  1988-36
# ... attempting to extract song_key:  1988-37
# ... attempting to extract song_key:  1988-38
# ... attempting to extract song_key:  1988-39
# ... attempting to extract song_key:  1988-40
# ... attempting to extract song_key:  1988-41
# ... attempting to extract song_key:  1988-42
# ... attempting to extract song_key:  1988-43
# ... attempting to extract song_key:  1988-44
# ... attempting to extract song_key:  1988-45
# ... attempting to extract song_key:  1988-46
# ... attempting to extract song_key:  1988-47
# ... attempting to extract song_key:  1988-48
# ... attempting to extract song_key:  1988-49
# ... attempting to extract song_key:  1988-50
# ... attempting to extract song_key:  1988-51
# ... attempting to extract song_key:  1988-52
# ... attempting to extract song_key:  1988-53
# ... attempting to extract song_key:  1988-54
# ... attempting to extract song_key:  1988-55
# ... attempting to extract song_key:  1988-56
# ... attempting to extract song_key:  1988-57
# ... attempting to extract song_key:  1988-58
# ... attempting to extract song_key:  1988-60
# ... attempting to extract song_key:  1988-61
# ... attempting to extract song_key:  1988-63
# ... attempting to extract song_key:  1988-64
# ... attempting to extract song_key:  1988-65
# ... attempting to extract song_key:  1988-66
# ... attempting to extract song_key:  1988-67
# ... attempting to extract song_key:  1988-68
# ... attempting to extract song_key:  1988-69
# ... attempting to extract song_key:  1988-70
# ... attempting to extract song_key:  1988-71
# ... attempting to extract song_key:  1988-72
# ... attempting to extract song_key:  1988-73
# ... attempting to extract song_key:  1988-74
# ... attempting to extract song_key:  1988-75
# ... attempting to extract song_key:  1988-76
# ... attempting to extract song_key:  1988-77
# ... attempting to extract song_key:  1988-78
# ... attempting to extract song_key:  1988-79
# ... attempting to extract song_key:  1988-80
# ... attempting to extract song_key:  1988-81
# ... attempting to extract song_key:  1988-82
# ... attempting to extract song_key:  1988-83
# ... attempting to extract song_key:  1988-84
# ... attempting to extract song_key:  1988-85
# ... attempting to extract song_key:  1988-86
# ... attempting to extract song_key:  1988-87
# ... attempting to extract song_key:  1988-88
# ... attempting to extract song_key:  1988-89
# ... attempting to extract song_key:  1988-90
# ... attempting to extract song_key:  1988-91
# ... attempting to extract song_key:  1988-92
# ... attempting to extract song_key:  1988-93
# ... attempting to extract song_key:  1988-94
# ... attempting to extract song_key:  1988-95
# ... attempting to extract song_key:  1988-96
# ... attempting to extract song_key:  1988-97
# ... attempting to extract song_key:  1988-98
# ... attempting to extract song_key:  1988-99
# ... attempting to extract song_key:  1988-100
# ... attempting to extract song_key:  1989-1
# ... attempting to extract song_key:  1989-2
# ... attempting to extract song_key:  1989-3
# ... attempting to extract song_key:  1989-4
# ... attempting to extract song_key:  1989-5
# ... attempting to extract song_key:  1989-6
# ... attempting to extract song_key:  1989-7
# ... attempting to extract song_key:  1989-8
# ... attempting to extract song_key:  1989-9
# ... attempting to extract song_key:  1989-10
# ... attempting to extract song_key:  1989-11
# ... attempting to extract song_key:  1989-12
# ... attempting to extract song_key:  1989-13
# ... attempting to extract song_key:  1989-14
# ... attempting to extract song_key:  1989-15
# ... attempting to extract song_key:  1989-16
# ... attempting to extract song_key:  1989-17
# ... attempting to extract song_key:  1989-18
# ... attempting to extract song_key:  1989-19
# ... attempting to extract song_key:  1989-20
# ... attempting to extract song_key:  1989-21
# ... attempting to extract song_key:  1989-22
# ... attempting to extract song_key:  1989-23
# ... attempting to extract song_key:  1989-24
# ... attempting to extract song_key:  1989-25
# ... attempting to extract song_key:  1989-26
# ... attempting to extract song_key:  1989-27
# ... attempting to extract song_key:  1989-28
# ... attempting to extract song_key:  1989-29
# ... attempting to extract song_key:  1989-30
# ... attempting to extract song_key:  1989-31
# ... attempting to extract song_key:  1989-32
# ... attempting to extract song_key:  1989-33
# ... attempting to extract song_key:  1989-34
# ... attempting to extract song_key:  1989-35
# ... attempting to extract song_key:  1989-36
# ... attempting to extract song_key:  1989-37
# ... attempting to extract song_key:  1989-38
# ... attempting to extract song_key:  1989-39
# ... attempting to extract song_key:  1989-40
# ... attempting to extract song_key:  1989-41
# ... attempting to extract song_key:  1989-42
# ... attempting to extract song_key:  1989-43
# ... attempting to extract song_key:  1989-44
# ... attempting to extract song_key:  1989-45
# ... attempting to extract song_key:  1989-46
# ... attempting to extract song_key:  1989-47
# ... attempting to extract song_key:  1989-48
# ... attempting to extract song_key:  1989-49
# ... attempting to extract song_key:  1989-50
# ... attempting to extract song_key:  1989-51
# ... attempting to extract song_key:  1989-52
# ... attempting to extract song_key:  1989-53
# ... attempting to extract song_key:  1989-54
# ... attempting to extract song_key:  1989-55
# ... attempting to extract song_key:  1989-56
# ... attempting to extract song_key:  1989-57
# ... attempting to extract song_key:  1989-58
# ... attempting to extract song_key:  1989-59
# ... attempting to extract song_key:  1989-60
# ... attempting to extract song_key:  1989-61
# ... attempting to extract song_key:  1989-62
# ... attempting to extract song_key:  1989-63
# ... attempting to extract song_key:  1989-64
# ... attempting to extract song_key:  1989-65
# ... attempting to extract song_key:  1989-66
# ... attempting to extract song_key:  1989-67
# ... attempting to extract song_key:  1989-68
# ... attempting to extract song_key:  1989-69
# ... attempting to extract song_key:  1989-70
# ... attempting to extract song_key:  1989-71
# ... attempting to extract song_key:  1989-72
# ... attempting to extract song_key:  1989-73
# ... attempting to extract song_key:  1989-74
# ... attempting to extract song_key:  1989-75
# ... attempting to extract song_key:  1989-76
# ... attempting to extract song_key:  1989-77
# ... attempting to extract song_key:  1989-78
# ... attempting to extract song_key:  1989-79
# ... attempting to extract song_key:  1989-80
# ... attempting to extract song_key:  1989-81
# ... attempting to extract song_key:  1989-82
# ... attempting to extract song_key:  1989-83
# ... attempting to extract song_key:  1989-84
# ... attempting to extract song_key:  1989-85
# ... attempting to extract song_key:  1989-86
# ... attempting to extract song_key:  1989-87
# ... attempting to extract song_key:  1989-88
# ... attempting to extract song_key:  1989-89
# ... attempting to extract song_key:  1989-90
# ... attempting to extract song_key:  1989-91
# ... attempting to extract song_key:  1989-92
# ... attempting to extract song_key:  1989-93
# ... attempting to extract song_key:  1989-94
# ... attempting to extract song_key:  1989-95
# ... attempting to extract song_key:  1989-96
# ... attempting to extract song_key:  1989-97
# ... attempting to extract song_key:  1989-99
# ... attempting to extract song_key:  1989-100
# ... attempting to extract song_key:  1990-1
# ... attempting to extract song_key:  1990-2
# ... attempting to extract song_key:  1990-3
# ... attempting to extract song_key:  1990-4
# ... attempting to extract song_key:  1990-5
# ... attempting to extract song_key:  1990-6
# ... attempting to extract song_key:  1990-7
# ... attempting to extract song_key:  1990-8
# ... attempting to extract song_key:  1990-9
# ... attempting to extract song_key:  1990-10
# ... attempting to extract song_key:  1990-11
# ... attempting to extract song_key:  1990-12
# ... attempting to extract song_key:  1990-13
# ... attempting to extract song_key:  1990-14
# ... attempting to extract song_key:  1990-15
# ... attempting to extract song_key:  1990-16
# ... attempting to extract song_key:  1990-17
# ... attempting to extract song_key:  1990-18
# ... attempting to extract song_key:  1990-19
# ... attempting to extract song_key:  1990-20
# ... attempting to extract song_key:  1990-21
# ... attempting to extract song_key:  1990-22
# ... attempting to extract song_key:  1990-23
# ... attempting to extract song_key:  1990-24
# ... attempting to extract song_key:  1990-25
# ... attempting to extract song_key:  1990-26
# ... attempting to extract song_key:  1990-27
# ... attempting to extract song_key:  1990-28
# ... attempting to extract song_key:  1990-29
# ... attempting to extract song_key:  1990-30
# ... attempting to extract song_key:  1990-31
# ... attempting to extract song_key:  1990-32
# ... attempting to extract song_key:  1990-33
# ... attempting to extract song_key:  1990-34
# ... attempting to extract song_key:  1990-35
# ... attempting to extract song_key:  1990-36
# ... attempting to extract song_key:  1990-37
# ... attempting to extract song_key:  1990-38
# ... attempting to extract song_key:  1990-39
# ... attempting to extract song_key:  1990-40
# ... attempting to extract song_key:  1990-41
# ... attempting to extract song_key:  1990-42
# ... attempting to extract song_key:  1990-43
# ... attempting to extract song_key:  1990-44
# ... attempting to extract song_key:  1990-45
# ... attempting to extract song_key:  1990-46
# ... attempting to extract song_key:  1990-47
# ... attempting to extract song_key:  1990-48
# ... attempting to extract song_key:  1990-49
# ... attempting to extract song_key:  1990-50
# ... attempting to extract song_key:  1990-51
# ... attempting to extract song_key:  1990-52
# ... attempting to extract song_key:  1990-53
# ... attempting to extract song_key:  1990-54
# ... attempting to extract song_key:  1990-55
# ... attempting to extract song_key:  1990-56
# ... attempting to extract song_key:  1990-57
# ... attempting to extract song_key:  1990-58
# ... attempting to extract song_key:  1990-59
# ... attempting to extract song_key:  1990-60
# ... attempting to extract song_key:  1990-61
# ... attempting to extract song_key:  1990-62
# ... attempting to extract song_key:  1990-63
# ... attempting to extract song_key:  1990-64
# ... attempting to extract song_key:  1990-65
# ... attempting to extract song_key:  1990-66
# ... attempting to extract song_key:  1990-67
# ... attempting to extract song_key:  1990-68
# ... attempting to extract song_key:  1990-69
# ... attempting to extract song_key:  1990-70
# ... attempting to extract song_key:  1990-71
# ... attempting to extract song_key:  1990-72
# ... attempting to extract song_key:  1990-73
# ... attempting to extract song_key:  1990-74
# ... attempting to extract song_key:  1990-75
# ... attempting to extract song_key:  1990-76
# ... attempting to extract song_key:  1990-77
# ... attempting to extract song_key:  1990-78
# ... attempting to extract song_key:  1990-79
# ... attempting to extract song_key:  1990-80
# ... attempting to extract song_key:  1990-81
# ... attempting to extract song_key:  1990-82
# ...
# ... attempting to extract song_key:  2011-39
# ... attempting to extract song_key:  2011-40
# ... attempting to extract song_key:  2011-41
# ... attempting to extract song_key:  2011-42
# ... attempting to extract song_key:  2011-43
# ... attempting to extract song_key:  2011-44
# ... attempting to extract song_key:  2011-45
# ... attempting to extract song_key:  2011-46
# ... attempting to extract song_key:  2011-47
# ... attempting to extract song_key:  2011-48
# ... attempting to extract song_key:  2011-49
# ... attempting to extract song_key:  2011-50
# ... attempting to extract song_key:  2011-51
# ... attempting to extract song_key:  2011-52
# ... attempting to extract song_key:  2011-53
# ... attempting to extract song_key:  2011-54
# ... attempting to extract song_key:  2011-55
# ... attempting to extract song_key:  2011-56
# ... attempting to extract song_key:  2011-57
# ... attempting to extract song_key:  2011-58
# ... attempting to extract song_key:  2011-59
# ... attempting to extract song_key:  2011-60
# ... attempting to extract song_key:  2011-61
# ... attempting to extract song_key:  2011-62
# ... attempting to extract song_key:  2011-63
# ... attempting to extract song_key:  2011-64
# ... attempting to extract song_key:  2011-65
# ... attempting to extract song_key:  2011-66
# ... attempting to extract song_key:  2011-67
# ... attempting to extract song_key:  2011-68
# ... attempting to extract song_key:  2011-69
# ... attempting to extract song_key:  2011-70
# ... attempting to extract song_key:  2011-71
# ... attempting to extract song_key:  2011-72
# ... attempting to extract song_key:  2011-73
# ... attempting to extract song_key:  2011-74
# ... attempting to extract song_key:  2011-75
# ... attempting to extract song_key:  2011-76
# ... attempting to extract song_key:  2011-77
# ... attempting to extract song_key:  2011-79
# ... attempting to extract song_key:  2011-80
# ... attempting to extract song_key:  2011-81
# ... attempting to extract song_key:  2011-82
# ... attempting to extract song_key:  2011-83
# ... attempting to extract song_key:  2011-84
# ... attempting to extract song_key:  2011-85
# ... attempting to extract song_key:  2011-86
# ... attempting to extract song_key:  2011-87
# ... attempting to extract song_key:  2011-88
# ... attempting to extract song_key:  2011-89
# ... attempting to extract song_key:  2011-90
# ... attempting to extract song_key:  2011-91
# ... attempting to extract song_key:  2011-92
# ... attempting to extract song_key:  2011-93
# ... attempting to extract song_key:  2011-94
# ... attempting to extract song_key:  2011-95
# ... attempting to extract song_key:  2011-96
# ... attempting to extract song_key:  2011-97
# ... attempting to extract song_key:  2011-98
# ... attempting to extract song_key:  2011-99
# ... attempting to extract song_key:  2011-100
# ... attempting to extract song_key:  2012-1
# ... attempting to extract song_key:  2012-2
# ... attempting to extract song_key:  2012-3
# ... attempting to extract song_key:  2012-4
# ... attempting to extract song_key:  2012-5
# ... attempting to extract song_key:  2012-6
# ... attempting to extract song_key:  2012-7
# ... attempting to extract song_key:  2012-8
# ... attempting to extract song_key:  2012-9
# ... attempting to extract song_key:  2012-10
# ... attempting to extract song_key:  2012-11
# ... attempting to extract song_key:  2012-12
# ... attempting to extract song_key:  2012-13
# ... attempting to extract song_key:  2012-14
# ... attempting to extract song_key:  2012-15
# ... attempting to extract song_key:  2012-16
# ... attempting to extract song_key:  2012-17
# ... attempting to extract song_key:  2012-18
# ... attempting to extract song_key:  2012-19
# ... attempting to extract song_key:  2012-20
# ... attempting to extract song_key:  2012-21
# ... attempting to extract song_key:  2012-22
# ... attempting to extract song_key:  2012-23
# ... attempting to extract song_key:  2012-24
# ... attempting to extract song_key:  2012-25
# ... attempting to extract song_key:  2012-26
# ... attempting to extract song_key:  2012-27
# ... attempting to extract song_key:  2012-28
# ... attempting to extract song_key:  2012-29
# ... attempting to extract song_key:  2012-30
# ... attempting to extract song_key:  2012-31
# ... attempting to extract song_key:  2012-33
# ... attempting to extract song_key:  2012-34
# ... attempting to extract song_key:  2012-35
# ... attempting to extract song_key:  2012-36
# ... attempting to extract song_key:  2012-37
# ... attempting to extract song_key:  2012-38
# ... attempting to extract song_key:  2012-39
# ... attempting to extract song_key:  2012-40
# ... attempting to extract song_key:  2012-41
# ... attempting to extract song_key:  2012-42
# ... attempting to extract song_key:  2012-43
# ... attempting to extract song_key:  2012-44
# ... attempting to extract song_key:  2012-45
# ... attempting to extract song_key:  2012-46
# ... attempting to extract song_key:  2012-47
# ... attempting to extract song_key:  2012-48
# ... attempting to extract song_key:  2012-49
# ... attempting to extract song_key:  2012-50
# ... attempting to extract song_key:  2012-51
# ... attempting to extract song_key:  2012-52
# ... attempting to extract song_key:  2012-53
# ... attempting to extract song_key:  2012-54
# ... attempting to extract song_key:  2012-55
# ... attempting to extract song_key:  2012-56
# ... attempting to extract song_key:  2012-57
# ... attempting to extract song_key:  2012-58
# ... attempting to extract song_key:  2012-59
# ... attempting to extract song_key:  2012-60
# ... attempting to extract song_key:  2012-61
# ... attempting to extract song_key:  2012-62
# ... attempting to extract song_key:  2012-63
# ... attempting to extract song_key:  2012-64
# ... attempting to extract song_key:  2012-65
# ... attempting to extract song_key:  2012-66
# ... attempting to extract song_key:  2012-67
# ... attempting to extract song_key:  2012-68
# ... attempting to extract song_key:  2012-69
# ... attempting to extract song_key:  2012-70
# ... attempting to extract song_key:  2012-71
# ... attempting to extract song_key:  2012-72
# ... attempting to extract song_key:  2012-73
# ... attempting to extract song_key:  2012-74
# ... attempting to extract song_key:  2012-75
# ... attempting to extract song_key:  2012-76
# ... attempting to extract song_key:  2012-77
# ... attempting to extract song_key:  2012-78
# ... attempting to extract song_key:  2012-79
# ... attempting to extract song_key:  2012-80
# ... attempting to extract song_key:  2012-81
# ... attempting to extract song_key:  2012-82
# ... attempting to extract song_key:  2012-84
# ... attempting to extract song_key:  2012-85
# ... attempting to extract song_key:  2012-86
# ... attempting to extract song_key:  2012-87
# ... attempting to extract song_key:  2012-88
# ... attempting to extract song_key:  2012-89
# ... attempting to extract song_key:  2012-90
# ... attempting to extract song_key:  2012-91
# ... attempting to extract song_key:  2012-92
# ... attempting to extract song_key:  2012-93
# ... attempting to extract song_key:  2012-94
# ... attempting to extract song_key:  2012-95
# ... attempting to extract song_key:  2012-96
# ... attempting to extract song_key:  2012-97
# ... attempting to extract song_key:  2012-98
# ... attempting to extract song_key:  2012-99
# ... attempting to extract song_key:  2012-100
# ... attempting to extract song_key:  2013-1
# ... attempting to extract song_key:  2013-2
# ... attempting to extract song_key:  2013-3
# ... attempting to extract song_key:  2013-4
# ... attempting to extract song_key:  2013-5
# ... attempting to extract song_key:  2013-6
# ... attempting to extract song_key:  2013-7
# ... attempting to extract song_key:  2013-8
# ... attempting to extract song_key:  2013-9
# ... attempting to extract song_key:  2013-10
# ... attempting to extract song_key:  2013-11
# ... attempting to extract song_key:  2013-12
# ... attempting to extract song_key:  2013-13
# ... attempting to extract song_key:  2013-14
# ... attempting to extract song_key:  2013-15
# ... attempting to extract song_key:  2013-16
# ... attempting to extract song_key:  2013-17
# ... attempting to extract song_key:  2013-18
# ... attempting to extract song_key:  2013-19
# ... attempting to extract song_key:  2013-21
# ... attempting to extract song_key:  2013-22
# ... attempting to extract song_key:  2013-24
# ... attempting to extract song_key:  2013-25
# ... attempting to extract song_key:  2013-26
# ... attempting to extract song_key:  2013-27
# ... attempting to extract song_key:  2013-28
# ... attempting to extract song_key:  2013-29
# ... attempting to extract song_key:  2013-30
# ... attempting to extract song_key:  2013-31
# ... attempting to extract song_key:  2013-32
# ... attempting to extract song_key:  2013-34
# ... attempting to extract song_key:  2013-35
# ... attempting to extract song_key:  2013-36
# ... attempting to extract song_key:  2013-37
# 'NoneType' object is not callable
# ... attempting to extract song_key:  2013-38
# ... attempting to extract song_key:  2013-39
# ... attempting to extract song_key:  2013-40
# ... attempting to extract song_key:  2013-41
# ... attempting to extract song_key:  2013-42
# ... attempting to extract song_key:  2013-43
# ... attempting to extract song_key:  2013-44
# ... attempting to extract song_key:  2013-45
# ... attempting to extract song_key:  2013-46
# ... attempting to extract song_key:  2013-47
# ... attempting to extract song_key:  2013-48
# ... attempting to extract song_key:  2013-49
# ... attempting to extract song_key:  2013-50
# ... attempting to extract song_key:  2013-51
# ... attempting to extract song_key:  2013-52
# ... attempting to extract song_key:  2013-53
# ... attempting to extract song_key:  2013-54
# ... attempting to extract song_key:  2013-55
# ... attempting to extract song_key:  2013-56
# ... attempting to extract song_key:  2013-57
# ... attempting to extract song_key:  2013-58
# ... attempting to extract song_key:  2013-59
# ... attempting to extract song_key:  2013-60
# ... attempting to extract song_key:  2013-61
# ... attempting to extract song_key:  2013-62
# ... attempting to extract song_key:  2013-63
# ... attempting to extract song_key:  2013-64
# ... attempting to extract song_key:  2013-65
# ... attempting to extract song_key:  2013-66
# ... attempting to extract song_key:  2013-67
# ... attempting to extract song_key:  2013-68
# ... attempting to extract song_key:  2013-69
# ... attempting to extract song_key:  2013-70
# ... attempting to extract song_key:  2013-71
# ... attempting to extract song_key:  2013-72
# ... attempting to extract song_key:  2013-73
# ... attempting to extract song_key:  2013-74
# ... attempting to extract song_key:  2013-75
# ... attempting to extract song_key:  2013-76
# ... attempting to extract song_key:  2013-77
# ... attempting to extract song_key:  2013-78
# ... attempting to extract song_key:  2013-79
# ... attempting to extract song_key:  2013-80
# ... attempting to extract song_key:  2013-81
# ... attempting to extract song_key:  2013-82
# ... attempting to extract song_key:  2013-83
# ... attempting to extract song_key:  2013-84
# ... attempting to extract song_key:  2013-85
# ... attempting to extract song_key:  2013-86
# ... attempting to extract song_key:  2013-87
# ... attempting to extract song_key:  2013-88
# ... attempting to extract song_key:  2013-89
# ... attempting to extract song_key:  2013-90
# ... attempting to extract song_key:  2013-91
# ... attempting to extract song_key:  2013-92
# ... attempting to extract song_key:  2013-93
# ... attempting to extract song_key:  2013-94
# ... attempting to extract song_key:  2013-96
# ... attempting to extract song_key:  2013-97
# ... attempting to extract song_key:  2013-98
# ... attempting to extract song_key:  2013-99
# ... attempting to extract song_key:  2013-100
# ... attempting to extract song_key:  2014-1
# ... attempting to extract song_key:  2014-2
# ... attempting to extract song_key:  2014-3
# ... attempting to extract song_key:  2014-4
# ... attempting to extract song_key:  2014-5
# ... attempting to extract song_key:  2014-6
# ... attempting to extract song_key:  2014-7
# ... attempting to extract song_key:  2014-8
# ... attempting to extract song_key:  2014-9
# ... attempting to extract song_key:  2014-10
# ... attempting to extract song_key:  2014-11
# ... attempting to extract song_key:  2014-12
# ... attempting to extract song_key:  2014-13
# ... attempting to extract song_key:  2014-14
# ... attempting to extract song_key:  2014-15
# ... attempting to extract song_key:  2014-16
# ... attempting to extract song_key:  2014-17
# ... attempting to extract song_key:  2014-18
# ... attempting to extract song_key:  2014-19
# ... attempting to extract song_key:  2014-20
# ... attempting to extract song_key:  2014-21
# ... attempting to extract song_key:  2014-22
# ... attempting to extract song_key:  2014-23
# ... attempting to extract song_key:  2014-24
# ... attempting to extract song_key:  2014-25
# ... attempting to extract song_key:  2014-26
# ... attempting to extract song_key:  2014-27
# ... attempting to extract song_key:  2014-28
# ... attempting to extract song_key:  2014-29
# ... attempting to extract song_key:  2014-30
# ... attempting to extract song_key:  2014-31
# ... attempting to extract song_key:  2014-32
# ... attempting to extract song_key:  2014-33
# ... attempting to extract song_key:  2014-34
# ... attempting to extract song_key:  2014-35
# ... attempting to extract song_key:  2014-36
# ... attempting to extract song_key:  2014-37
# ... attempting to extract song_key:  2014-38
# ... attempting to extract song_key:  2014-39
# ... attempting to extract song_key:  2014-40
# ... attempting to extract song_key:  2014-41
# ... attempting to extract song_key:  2014-42
# ... attempting to extract song_key:  2014-43
# ... attempting to extract song_key:  2014-44
# ... attempting to extract song_key:  2014-45
# ... attempting to extract song_key:  2014-46
# ... attempting to extract song_key:  2014-47
# ... attempting to extract song_key:  2014-48
# ... attempting to extract song_key:  2014-49
# ... attempting to extract song_key:  2014-50
# ... attempting to extract song_key:  2014-51
# ... attempting to extract song_key:  2014-52
# ... attempting to extract song_key:  2014-53
# ... attempting to extract song_key:  2014-55
# ... attempting to extract song_key:  2014-56
# ... attempting to extract song_key:  2014-57
# ... attempting to extract song_key:  2014-59
# ... attempting to extract song_key:  2014-60
# ... attempting to extract song_key:  2014-61
# ... attempting to extract song_key:  2014-62
# ... attempting to extract song_key:  2014-63
# ... attempting to extract song_key:  2014-64
# ... attempting to extract song_key:  2014-65
# ... attempting to extract song_key:  2014-66
# ... attempting to extract song_key:  2014-67
# ... attempting to extract song_key:  2014-68
# ... attempting to extract song_key:  2014-69
# ... attempting to extract song_key:  2014-70
# ... attempting to extract song_key:  2014-71
# ... attempting to extract song_key:  2014-72
# ... attempting to extract song_key:  2014-73
# ... attempting to extract song_key:  2014-74
# ... attempting to extract song_key:  2014-75
# ... attempting to extract song_key:  2014-76
# ... attempting to extract song_key:  2014-77
# ... attempting to extract song_key:  2014-78
# ... attempting to extract song_key:  2014-79
# ... attempting to extract song_key:  2014-80
# ... attempting to extract song_key:  2014-81
# ... attempting to extract song_key:  2014-82
# ... attempting to extract song_key:  2014-83
# ... attempting to extract song_key:  2014-84
# ... attempting to extract song_key:  2014-85
# ... attempting to extract song_key:  2014-86
# ... attempting to extract song_key:  2014-87
# ... attempting to extract song_key:  2014-88
# ... attempting to extract song_key:  2014-89
# ... attempting to extract song_key:  2014-90
# 'NoneType' object is not callable
# ... attempting to extract song_key:  2014-91
# ... attempting to extract song_key:  2014-93
# ... attempting to extract song_key:  2014-94
# ... attempting to extract song_key:  2014-95
# ... attempting to extract song_key:  2014-96
# ... attempting to extract song_key:  2014-97
# ... attempting to extract song_key:  2014-98
# ... attempting to extract song_key:  2014-99
# ... attempting to extract song_key:  2014-100
# CPU times: user 3min 24s, sys: 4.25 s, total: 3min 28s
# Wall time: 4min 11s

# %%
print
print "how many new lyrics were downloaded? ", len(new_refs0)
print "how many results were in the cache? ", len(cache_refs0)
print "how many issues were encountered? ", len(issues0)
# Out:
# how many new lyrics were downloaded?  3406
# how many results were in the cache?  1
# how many issues were encountered?  93

# %% [markdown]
# ##Save Off Issues

# %%
# save 70s issues
with open('../../data/harvested/lyrics-extracted-issues_1970s.json', 'w') as fp:
    json.dump(issues70, fp)

# %%
# save remaining issues
with open('../../data/harvested/lyrics-extracted-issues_after_1970s.json', 'w') as fp:
    json.dump(issues0, fp)

# %% [markdown]
# ##Add Lyrics to Dataframe
# **The rules are the following:**
# * if a cached lyric extraction is available, it goes into df['lyrics']
# * else if existing df['lyrics'] is valid, it is the keeper
# * else if df['lyric_abstract'] is valid, it goes into df ['lyrics']
#
# Collect the metrics on the processing

# %%
def addExtractedLyrics(lyricsdf, debug=False, bogus_threshold=10):    
        
    new = 0
    exist = 0
    abstract = 0
    invalid = 0
    
    def pickBestLyric(r, debug=False, bogus_threshold=10):        
        song_key = r[1]['song_key']
        lyrics = r[1]['lyrics']
        abstract = r[1]['lyrics_abstract']
        
        if not isinstance(abstract,str) or len(abstract) < bogus_threshold:
            abstract = ""
        
        if not isinstance(lyrics,str) or len(lyrics) < bogus_threshold:
            lyrics = ""
        
        tnew = 0
        texist = 0
        tabstract = 0
        tinvalid = 0
        
        best = lyrics #default
        
        pathsd = buildPathsDictFor(song_key) 
        
        # test for cached being available, if so, use
        cache_hit = False
        if isNonZeroFile(pathsd['success_path']):                
            # Read text from pathsd
            with io.open(pathsd['success_path'], "r", encoding='utf-8') as text_file:
                tmp = text_file.read().encode('ascii', 'ignore') #for dataframe, want ascii. 
            
            # Test for validity to avoid some bogus information
            if len(tmp) > bogus_threshold:
                best = tmp
                cache_hit = True
                
        # test for cache hit valid    
        if cache_hit:
            tnew += 1
            if debug:
                print "... cache is best for song_key --> ", song_key
                
        # test for abstract being better than lyric
        elif len(lyrics) < len(abstract):
            best = abstract
            tabstract +=1
            if debug:
                print "... `lyrics_abstract` is best for song_key --> ", song_key
            
        # stick with original, though ok    
        elif len(lyrics) >= bogus_threshold:
            texist +=1
            if debug:
                print "... existing at `lyrics` is best for song_key --> ", song_key
            
        # stick with original, though bad    
        else:
            tinvalid += 1
            if debug:
                print "... invalid `lyrics` (last option) for song_key --> ", song_key
        
        return best, (tnew,texist,tabstract,tinvalid)
    
    #use a copy of provided df
    df = lyricsdf.copy(deep=True).reset_index() 
    
    #build up new lyrics based on rules
    best_lyrics = []    
    for r in df.iterrows():
        b, t = pickBestLyric(r,debug=debug,bogus_threshold=bogus_threshold)
        #lyric winner
        best_lyrics.append(b)
        #counters
        new += t[0]
        exist += t[1]
        abstract += t[2]
        invalid += t[3]
    
    ## Get double use:
    # 1. apply to df on all 'lyrics' column
    idx = -1    
    for lyrics in best_lyrics:
        idx +=1
        
        # go ahead and normalize best lyrics.
        b = normalizeLyrics(lyrics)
        
        df.loc[idx, 'lyrics'] = b    
        
    #apply selectively on `lyrics_abstract` column with some more manipulation
    idx = -1  
    a_threshold = 280
    for lyrics in best_lyrics:
        idx +=1
        
        a = df.loc[idx, 'lyrics_abstract']
        awinner = "" # set the initial winner to empty
        
        if debug:
            print "type of abstract? ", type(a)
        
        if not isinstance(a,str) or len(a) < bogus_threshold:
            a = ""
        else:    
            awinner = a # can set a winner to a after checking conditions
        
        # only go further if have something worthwhile to compare
        if isinstance(lyrics,str) and len(lyrics) >= bogus_threshold:
            if len(lyrics) >= a_threshold or len(lyrics) > len(awinner):             
                awinner = lyrics
                    
        # some final cleanup    
        if awinner:
            
            # trim down if needed.
            if len(awinner) > 280:
                awinner = awinner[:280]
            
            # strip trailing '[...]'
            awinner = awinner.replace('[...]','')
            
            # handle common cleaning
            awinner = normalizeLyrics(awinner)
            
            # standardize ending
            awinner = awinner + "[...]"  
            
            if debug:
                print "changing abstract --> ", awinner
        
        # regardless, update with best abstract, whether empty or lyrics substring or same.
        df.loc[idx, 'lyrics_abstract'] = awinner
    
    return df, (new,exist,abstract,invalid)

# %% [markdown]
# ##Quick Test on Single Record

# %%
tdf, ttuple = addExtractedLyrics(lyricsdf[lyricsdf.song_key == "1970-1"], debug=True)   
print
print "how many new lyrics applied? ", ttuple[0]
print "how many existing lyrics were preserved? ", ttuple[1]
print "how many lyric_abstract were used? ", ttuple[2]
print "how many lyrics are invalid (after other rules)? ", ttuple[3]
# Out:
# ... cache is best for song_key -->  1970-1
# type of abstract?  <type 'str'>
# changing abstract -->  When you're weary. Feeling small. When tears are in your eyes. I will dry them all. I'm on your side. When times get rough. And friends just can't be found. Like a bridge over troubled water. I will lay me down. Like a bridge over troubled water. I will lay me down. When you're d[...]
#
# how many new lyrics applied?  1
# how many existing lyrics were preserved?  0
# how many lyric_abstract were used?  0
# how many lyrics are invalid (after other rules)?  0

# %%
tdf.head()
# Out:
#    index  position  year                                         title.href                       title               artist                                             lyrics  decade song_key                                         lyrics_url                                    lyrics_abstract
# 0      0         1  1970  https://en.wikipedia.org/wiki/Bridge_over_Trou...  Bridge over Troubled Water  Simon and Garfunkel  When you're weary. Feeling small. When tears a...    1970   1970-1  http://lyrics.wikia.com/Simon_And_Garfunkel:Br...  When you're weary. Feeling small. When tears a...

# %% [markdown]
# ##Full Processing

# %%
print "execution start --> {}".format(time.strftime('%a, %d %b %Y %H:%M:%S', time.localtime()))
# Out:
# execution start --> Mon, 23 Nov 2015 20:47:49

# %%
# %%time
mlyricsdf, rtuple = addExtractedLyrics(lyricsdf)   
print
print "how many new lyrics applied? ", rtuple[0]
print "how many existing lyrics were preserved? ", rtuple[1]
print "how many lyric_abstract were used? ", rtuple[2]
print "how many lyrics are invalid (after other rules)? ", rtuple[3]
# Out:
# how many new lyrics applied?  4293
# how many existing lyrics were preserved?  43
# how many lyric_abstract were used?  61
# how many lyrics are invalid (after other rules)?  103
# CPU times: user 10.2 s, sys: 6.49 s, total: 16.7 s
# Wall time: 32.5 s

# %%
mlyricsdf.shape
# Out:
# (4500, 11)

# %%
mlyricsdf.head()
# Out:
#    index  position  year                                         title.href                              title               artist                                             lyrics  decade song_key                                         lyrics_url                                    lyrics_abstract
# 0      0         1  1970  https://en.wikipedia.org/wiki/Bridge_over_Trou...         Bridge over Troubled Water  Simon and Garfunkel  When you're weary. Feeling small. When tears a...    1970   1970-1  http://lyrics.wikia.com/Simon_And_Garfunkel:Br...  When you're weary. Feeling small. When tears a...
# 1      1         2  1970  https://en.wikipedia.org/wiki/(They_Long_to_Be...     (They Long to Be) Close to You       The Carpenters  Why do birds suddenly appear. Everytime you ar...    1970   1970-2  http://lyrics.wikia.com/Carpenters:%28They_Lon...  Why do birds suddenly appear. Everytime you ar...
# 2      2         3  1970  https://en.wikipedia.org/wiki/American_Woman_(...                     American Woman        The Guess Who  Mmm, da da da. Mmm, mmm, da da da. Mmm, mmm, d...    1970   1970-3  http://lyrics.wikia.com/The_Guess_Who:American...  Mmm, da da da. Mmm, mmm, da da da. Mmm, mmm, d...
# 3      3         4  1970  https://en.wikipedia.org/wiki/Raindrops_Keep_F...  Raindrops Keep Fallin' on My Head          B.J. Thomas  Raindrops are falling on my head. And just lik...    1970   1970-4  http://lyrics.wikia.com/B.J._Thomas:Raindrops_...  Raindrops are falling on my head. And just lik...
# 4      4         5  1970  https://en.wikipedia.org/wiki/War_(Edwin_Starr...                                War          Edwin Starr  War, huh, yeah. What is it good for? Absolutel...    1970   1970-5            http://lyrics.wikia.com/Edwin_Starr:War  War, huh, yeah. What is it good for? Absolutel...

# %% [markdown]
# ## Save DataFrame

# %%
# save mlyricsdf
mlyricsdf.to_csv("../../data/conditioned/master-lyricsdf-extracted.csv",index=False)
